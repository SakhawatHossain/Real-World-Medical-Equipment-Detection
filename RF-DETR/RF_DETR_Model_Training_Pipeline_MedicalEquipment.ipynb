# %% [markdown]
# # RF-DETR Model Training Notebook on Medical Equipment Detection Dataset
#
# ---
#
# RF-DETR is a real-time, transformer-based object detection model architecture developed by Roboflow and released under the Apache 2.0 license.
#
# ![rf-detr-coco-rf100-vl-8](https://media.roboflow.com/rfdetr/pareto.png)
#
# The RF-DETR family of models stands as the quickest and most precise in object detection across all sizes. RF-DETR has achieved over 60 mAP on the Microsoft COCO benchmark, a leading measure of object detection performance. It also sets new records on RF100-VL, a benchmark that shows how well models adapt to real-world problems beyond standard datasets.
#
# The RF-DETR model group includes five sizes: Nano, Small, Medium, Base, and Large. These models offer a range of options for different needs. For example, RF-DETR-Nano is 11 mAP higher than YOLO11-n (on mAP50:95) and runs 0.17 ms faster. Likewise, RF-DETR-Small is 1.8 mAP better than YOLO11-x (the biggest YOLO11 model) and speeds things up by a good 7.77 ms. This wide range of models makes RF-DETR a great choice for many real-world uses, from small devices that need to be super fast to bigger jobs that demand top precision.
#
# RF-DETR is small enough to run on edge devices, making it perfect for deployments that need both high accuracy and real-time performance. You can easily get started with any of the RF-DETR models, as they're ready for training in the cloud with Roboflow or through the free RF-DETR Python package.

# %% [markdown]
# ## Environment setup

# %% [markdown]
# ### Configure API Key
#
# To fine-tune RF-DETR, you need to provide your Roboflow API key. Follow these steps:
#
# - Go to your [`Roboflow Settings`](https://app.roboflow.com/settings/api) page. Click `Copy` to copy your private API key.
# - In Colab, go to the left pane and click on `Secrets` (🔑).
#     - Store your Roboflow API Key under the name `ROBOFLOW_API_KEY`.

# %%
import os
from google.colab import userdata

os.environ["ROBOFLOW_API_KEY"] = ""

# %% [markdown]
# ### Check GPU availability
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `T4 GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Fri Sep 26 10:32:22 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:00:05.0 Off |                    0 |
# | N/A   32C    P0             56W /  400W |       0MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### Install dependencies
#
# Installs RF-DETR version 1.2.1 or higher (which includes the new Nano, Small, and Medium checkpoints), along with Supervision for benchmarking and Roboflow for pulling datasets and uploading models to the Roboflow platform.

# %%
# !pip install -q rfdetr==1.2.1 supervision==0.26.1 roboflow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.3/266.3 kB 20.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.3/131.3 kB 13.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.2/207.2 kB 19.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.7/88.7 kB 8.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 51.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 81.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 119.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 26.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 372.8/372.8 kB 34.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 80.4 MB/s eta 0:00:00
#   Building wheel for fairscale (pyproject.toml) ... done

# %% [markdown]
# ### Download example data
#
# Downloads example images for testing. You can use these or replace them with your own images.

# %%
# !wget -q https://media.roboflow.com/notebooks/examples/dog-2.jpeg
# !wget -q https://media.roboflow.com/notebooks/examples/dog-3.jpeg

# %% [markdown]
# ## Inference with Pre-trained COCO Model
#
# Runs inference on an example image using a pretrained RF-DETR Medium model (trained on COCO). To use a different model size, simply replace `RFDETRMedium` with `RFDETRNano`, `RFDETRSmall`, `RFDETRBase` or `RFDETRLarge` as needed.

# %%
import numpy as np
import supervision as sv

from PIL import Image

from rfdetr import RFDETRMedium
from rfdetr.util.coco_classes import COCO_CLASSES

image = Image.open("dog-2.jpeg")

model = RFDETRMedium(resolution=640)
model.optimize_for_inference()

detections = model.predict(image, threshold=0.5)

color = sv.ColorPalette.from_hex([
    "#ffff00", "#ff9b00", "#ff8080", "#ff66b2", "#ff66ff", "#b266ff",
    "#9999ff", "#3399ff", "#66ffff", "#33ff99", "#66ff66", "#99ff00"
])
text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)

bbox_annotator = sv.BoxAnnotator(color=color, thickness=thickness)
label_annotator = sv.LabelAnnotator(
    color=color,
    text_color=sv.Color.BLACK,
    text_scale=text_scale,
    smart_position=True
)

labels = [
    f"{COCO_CLASSES[class_id]} {confidence:.2f}"
    for class_id, confidence
    in zip(detections.class_id, detections.confidence)
]

annotated_image = image.copy()
annotated_image = bbox_annotator.annotate(annotated_image, detections)
annotated_image = label_annotator.annotate(annotated_image, detections, labels)
annotated_image.thumbnail((800, 800))
annotated_image
# Out:
# rf-detr-medium.pth: 100%|██████████| 386M/386M [00:18<00:00, 22.5MiB/s]
# Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Loading pretrain weights
# `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: torch.as_tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
# TracerWarning: Iterating over a tensor might cause the trace to be incorrect. Passing a tensor of different shape won't change the number of iterations executed (and might lead to errors or silently give incorrect results).
# TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
# TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
# UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4322.)
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Iterating over a tensor might cause the trace to be incorrect. Passing a tensor of different shape won't change the number of iterations executed (and might lead to errors or silently give incorrect results).
# TracerWarning: Iterating over a tensor might cause the trace to be incorrect. Passing a tensor of different shape won't change the number of iterations executed (and might lead to errors or silently give incorrect results).
# <PIL.Image.Image image mode=RGB size=450x800>

# %% [markdown]
# ## Download Dataset from Roboflow Universe
#
# RF-DETR expects the dataset to be in COCO format. Divide your dataset into three subdirectories: `train`, `valid`, and `test`. Each subdirectory should contain its own `_annotations.coco.json` file that holds the annotations for that particular split, along with the corresponding image files. Below is an example of the directory structure:
#
# ```
# dataset/
# ├── train/
# │   ├── _annotations.coco.json
# │   ├── image1.jpg
# │   ├── image2.jpg
# │   └── ... (other image files)
# ├── valid/
# │   ├── _annotations.coco.json
# │   ├── image1.jpg
# │   ├── image2.jpg
# │   └── ... (other image files)
# └── test/
#     ├── _annotations.coco.json
#     ├── image1.jpg
#     ├── image2.jpg
#     └── ... (other image files)
# ```
#
# [Roboflow](https://roboflow.com/annotate) allows you to create object detection datasets from scratch or convert existing datasets from formats like YOLO, and then export them in COCO JSON format for training. You can also explore [Roboflow Universe](https://universe.roboflow.com/) to find pre-labeled datasets for a range of use cases.

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="")
project = rf.workspace(").project("")
version = project.version(2)
dataset = version.download("coco")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in medical-first-aid-equipment-30-2 to coco:: 100%|██████████| 225281/225281 [00:13<00:00, 16700.24it/s]
# Extracting Dataset Version Zip to medical-first-aid-equipment-30-2 in coco:: 100%|██████████| 4512/4512 [00:00<00:00, 5938.74it/s]

# %% [markdown]
# ## Train RF-DETR on custom dataset
#
# ### Choose the right `batch_size`
#
# Different GPUs have different amounts of VRAM (video memory), which limits how much data they can handle at once during training. To make training work well on any machine, you can adjust two settings: `batch_size` and `grad_accum_steps`. These control how many samples are processed at a time. The key is to keep their product equal to 16 — that’s our recommended total batch size. For example, on powerful GPUs like the A100, set `batch_size=16` and `grad_accum_steps=1`. On smaller GPUs like the T4, use `batch_size=4` and `grad_accum_steps=4`. We use a method called gradient accumulation, which lets the model simulate training with a larger batch size by gradually collecting updates before adjusting the weights.

# %%
from rfdetr import RFDETRMedium

model = RFDETRMedium()

model.train(dataset_dir=dataset.location, epochs=30, batch_size=16, grad_accum_steps=2)
# Out:
# Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Loading pretrain weights
# WARNING:rfdetr.detr:num_classes mismatch: model has 90 classes, but your dataset has 31 classes
# reinitializing your detection head with 31 classes.
# TensorBoard logging initialized. To monitor logs, use 'tensorboard --logdir output' and open http://localhost:6006/ in browser.
# Not using distributed mode
# git:
#   sha: N/A, status: clean, branch: N/A
#
# Namespace(num_classes=31, grad_accum_steps=2, amp=True, lr=0.0001, lr_encoder=0.00015, batch_size=16, weight_decay=0.0001, epochs=30, lr_drop=100, clip_max_norm=0.1, lr_vit_layer_decay=0.8, lr_component_decay=0.7, do_benchmark=False, dropout=0, drop_path=0.0, drop_mode='standard', drop_schedule='constant', cutoff_epoch=0, pretrained_encoder=None, pretrain_weights='rf-detr-medium.pth', pretrain_exclude_keys=None, pretrain_keys_modify_to_load=None, pretrained_distiller=None, encoder='dinov2_windowed_small', vit_encoder_num_layers=12, window_block_indexes=None, position_embedding='sine', out_feature_indexes=[3, 6, 9, 12], freeze_encoder=False, layer_norm=True, rms_norm=False, backbone_lora=False, force_no_pretrain=False, dec_layers=4, dim_feedforward=2048, hidden_dim=256, sa_nheads=8, ca_nheads=16, num_queries=300, group_detr=13, two_stage=True, projector_scale=['P4'], lite_refpoint_refine=True, num_select=300, dec_n_points=2, decoder_norm='LN', bbox_reparam=True, freeze_batch_norm=False, set_cost_class=2, set_cost_bbox=5, set_cost_giou=2, cls_loss_coef=1.0, bbox_loss_coef=5, giou_loss_coef=2, focal_alpha=0.25, aux_loss=True, sum_group_losses=False, use_varifocal_loss=False, use_position_supervised_loss=False, ia_bce_loss=True, dataset_file='roboflow', coco_path=None, dataset_dir='/content/medical-first-aid-equipment-30-2', square_resize_div_64=True, output_dir='output', dont_save_weights=False, checkpoint_interval=10, seed=42, resume='', start_epoch=0, eval=False, use_ema=True, ema_decay=0.993, ema_tau=100, num_workers=2, device='cuda', world_size=1, dist_url='env://', sync_bn=True, fp16_eval=False, encoder_only=False, backbone_only=False, resolution=576, use_cls_token=False, multi_scale=True, expanded_scales=True, do_random_resize_via_padding=False, warmup_epochs=0, lr_scheduler='step', lr_min_factor=0.0, early_stopping=False, early_stopping_patience=10, early_stopping_min_delta=0.001, early_stopping_use_ema=False, gradient_checkpointing=False, patch_size=16, num_windows=2, positional_encoding_size=36, tensorboard=True, wandb=False, project=None, run=None, class_names=['Analog_BPM', 'Analogue_Thermometer', 'Artery_Forcep', 'Cheatle_Forceps', 'Cotton', 'Digital_BPM', 'Digital_Thermometer', 'First_Aid_Box', 'Foam_Roller', 'Forceps_Jar', 'Galli_Pot', 'Glucometer', 'Hand_Gloves', 'Hexasol', 'Hot_water_Bag', 'Kidney_Tray', 'Neurological_Medical_Reflex_Hammer', 'One_Time_Bandage', 'Oral_Rehydration_Salt', 'Oxygen_Cylinder', 'Pulse_Oximeter', 'Solution_Saline', 'Sterile_Gauze_Pads', 'Stethoscopes', 'Surgical_Blade', 'Surgical_Scalpel_Handle', 'Surgical_Scissors', 'Surgical_Tape', 'Syringe', 'Tweezer'], run_test=True, distributed=False)
# number of params: 33471578
# [736]
# loading annotations into memory...
# Done (t=0.05s)
# creating index...
# index created!
# [736]
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# [736]
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Get benchmark
# Start training
# Grad accum steps:  2
# Total batch size:  32
# LENGTH OF DATA LOADER: 98
# Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
# Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
# Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
# Epoch: [0]  [ 0/98]  eta: 0:06:00  lr: 0.000100  class_error: 98.01  loss: 12.7086 (12.7086)  loss_ce: 1.0281 (1.0281)  loss_bbox: 0.6593 (0.6593)  loss_giou: 0.7612 (0.7612)  loss_ce_0: 0.9771 (0.9771)  loss_bbox_0: 0.7715 (0.7715)  loss_giou_0: 0.8602 (0.8602)  loss_ce_1: 1.0090 (1.0090)  loss_bbox_1: 0.7080 (0.7080)  loss_giou_1: 0.8010 (0.8010)  loss_ce_2: 1.0217 (1.0217)  loss_bbox_2: 0.6873 (0.6873)  loss_giou_2: 0.7766 (0.7766)  loss_ce_enc: 0.9753 (0.9753)  loss_bbox_enc: 0.8062 (0.8062)  loss_giou_enc: 0.8661 (0.8661)  loss_ce_unscaled: 1.0281 (1.0281)  class_error_unscaled: 98.0057 (98.0057)  loss_bbox_unscaled: 0.1319 (0.1319)  loss_giou_unscaled: 0.3806 (0.3806)  cardinality_error_unscaled: 3841.2500 (3841.2500)  loss_ce_0_unscaled: 0.9771 (0.9771)  loss_bbox_0_unscaled: 0.1543 (0.1543)  loss_giou_0_unscaled: 0.4301 (0.4301)  cardinality_error_0_unscaled: 3857.1250 (3857.1250)  loss_ce_1_unscaled: 1.0090 (1.0090)  loss_bbox_1_unscaled: 0.1416 (0.1416)  loss_giou_1_unscaled: 0.4005 (0.4005)  cardinality_error_1_unscaled: 3731.6250 (3731.6250)  loss_ce_2_unscaled: 1.0217 (1.0217)  loss_bbox_2_unscaled: 0.1375 (0.1375)  loss_giou_2_unscaled: 0.3883 (0.3883)  cardinality_error_2_unscaled: 3847.8750 (3847.8750)  loss_ce_enc_unscaled: 0.9753 (0.9753)  loss_bbox_enc_unscaled: 0.1612 (0.1612)  loss_giou_enc_unscaled: 0.4330 (0.4330)  cardinality_error_enc_unscaled: 3892.0625 (3892.0625)  time: 3.6777  data: 1.5221  max mem: 12519
# Epoch: [0]  [10/98]  eta: 0:01:53  lr: 0.000100  class_error: 96.29  loss: 10.9715 (11.0627)  loss_ce: 1.1977 (1.1757)  loss_bbox: 0.3591 (0.4015)  loss_giou: 0.4702 (0.5143)  loss_ce_0: 1.1290 (1.1025)  loss_bbox_0: 0.5546 (0.5415)  loss_giou_0: 0.5979 (0.6475)  loss_ce_1: 1.1723 (1.1424)  loss_bbox_1: 0.4405 (0.4614)  loss_giou_1: 0.5225 (0.5787)  loss_ce_2: 1.1877 (1.1654)  loss_bbox_2: 0.3937 (0.4229)  loss_giou_2: 0.4882 (0.5369)  loss_ce_enc: 1.0682 (1.0726)  loss_bbox_enc: 0.5954 (0.5975)  loss_giou_enc: 0.7046 (0.7019)  loss_ce_unscaled: 1.1977 (1.1757)  class_error_unscaled: 96.2865 (95.7949)  loss_bbox_unscaled: 0.0718 (0.0803)  loss_giou_unscaled: 0.2351 (0.2572)  cardinality_error_unscaled: 3841.2500 (3835.9602)  loss_ce_0_unscaled: 1.1290 (1.1025)  loss_bbox_0_unscaled: 0.1109 (0.1083)  loss_giou_0_unscaled: 0.2990 (0.3237)  cardinality_error_0_unscaled: 3844.8125 (3843.3750)  loss_ce_1_unscaled: 1.1723 (1.1424)  loss_bbox_1_unscaled: 0.0881 (0.0923)  loss_giou_1_unscaled: 0.2613 (0.2893)  cardinality_error_1_unscaled: 3624.6875 (3631.1705)  loss_ce_2_unscaled: 1.1877 (1.1654)  loss_bbox_2_unscaled: 0.0787 (0.0846)  loss_giou_2_unscaled: 0.2441 (0.2685)  cardinality_error_2_unscaled: 3823.4375 (3819.5511)  loss_ce_enc_unscaled: 1.0682 (1.0726)  loss_bbox_enc_unscaled: 0.1191 (0.1195)  loss_giou_enc_unscaled: 0.3523 (0.3509)  cardinality_error_enc_unscaled: 3882.0625 (3875.8977)  time: 1.2930  data: 0.2202  max mem: 15255
# Epoch: [0]  [20/98]  eta: 0:01:31  lr: 0.000100  class_error: 87.64  loss: 10.2900 (10.5562)  loss_ce: 1.2431 (1.2214)  loss_bbox: 0.3195 (0.3417)  loss_giou: 0.4030 (0.4433)  loss_ce_0: 1.1899 (1.1586)  loss_bbox_0: 0.3983 (0.4486)  loss_giou_0: 0.4922 (0.5544)  loss_ce_1: 1.2129 (1.1918)  loss_bbox_1: 0.3564 (0.3910)  loss_giou_1: 0.4623 (0.4968)  loss_ce_2: 1.2337 (1.2120)  loss_bbox_2: 0.3402 (0.3604)  loss_giou_2: 0.4234 (0.4619)  loss_ce_enc: 1.1360 (1.1158)  loss_bbox_enc: 0.4816 (0.5260)  loss_giou_enc: 0.5895 (0.6326)  loss_ce_unscaled: 1.2431 (1.2214)  class_error_unscaled: 93.1393 (93.8043)  loss_bbox_unscaled: 0.0639 (0.0683)  loss_giou_unscaled: 0.2015 (0.2216)  cardinality_error_unscaled: 3835.8125 (3834.3661)  loss_ce_0_unscaled: 1.1899 (1.1586)  loss_bbox_0_unscaled: 0.0797 (0.0897)  loss_giou_0_unscaled: 0.2461 (0.2772)  cardinality_error_0_unscaled: 3820.5000 (3827.5446)  loss_ce_1_unscaled: 1.2129 (1.1918)  loss_bbox_1_unscaled: 0.0713 (0.0782)  loss_giou_1_unscaled: 0.2312 (0.2484)  cardinality_error_1_unscaled: 3547.5000 (3563.9345)  loss_ce_2_unscaled: 1.2337 (1.2120)  loss_bbox_2_unscaled: 0.0680 (0.0721)  loss_giou_2_unscaled: 0.2117 (0.2310)  cardinality_error_2_unscaled: 3816.4375 (3820.8482)  loss_ce_enc_unscaled: 1.1360 (1.1158)  loss_bbox_enc_unscaled: 0.0963 (0.1052)  loss_giou_enc_unscaled: 0.2947 (0.3163)  cardinality_error_enc_unscaled: 3860.6250 (3842.7024)  time: 1.0443  data: 0.0820  max mem: 15828
# Epoch: [0]  [30/98]  eta: 0:01:15  lr: 0.000100  class_error: 84.90  loss: 9.6733 (10.2288)  loss_ce: 1.3099 (1.2510)  loss_bbox: 0.2459 (0.3067)  loss_giou: 0.3110 (0.4011)  loss_ce_0: 1.2756 (1.1978)  loss_bbox_0: 0.3008 (0.3919)  loss_giou_0: 0.3627 (0.4918)  loss_ce_1: 1.2869 (1.2254)  loss_bbox_1: 0.2706 (0.3472)  loss_giou_1: 0.3340 (0.4451)  loss_ce_2: 1.3054 (1.2433)  loss_bbox_2: 0.2577 (0.3210)  loss_giou_2: 0.3158 (0.4161)  loss_ce_enc: 1.2198 (1.1559)  loss_bbox_enc: 0.3656 (0.4658)  loss_giou_enc: 0.4701 (0.5686)  loss_ce_unscaled: 1.3099 (1.2510)  class_error_unscaled: 87.6518 (90.3186)  loss_bbox_unscaled: 0.0492 (0.0613)  loss_giou_unscaled: 0.1555 (0.2005)  cardinality_error_unscaled: 3841.2500 (3837.8649)  loss_ce_0_unscaled: 1.2756 (1.1978)  loss_bbox_0_unscaled: 0.0602 (0.0784)  loss_giou_0_unscaled: 0.1813 (0.2459)  cardinality_error_0_unscaled: 3818.1250 (3826.8327)  loss_ce_1_unscaled: 1.2869 (1.2254)  loss_bbox_1_unscaled: 0.0541 (0.0694)  loss_giou_1_unscaled: 0.1670 (0.2225)  cardinality_error_1_unscaled: 3520.6250 (3565.2419)  loss_ce_2_unscaled: 1.3054 (1.2433)  loss_bbox_2_unscaled: 0.0515 (0.0642)  loss_giou_2_unscaled: 0.1579 (0.2081)  cardinality_error_2_unscaled: 3833.6250 (3830.0968)  loss_ce_enc_unscaled: 1.2198 (1.1559)  loss_bbox_enc_unscaled: 0.0731 (0.0932)  loss_giou_enc_unscaled: 0.2350 (0.2843)  cardinality_error_enc_unscaled: 3757.4375 (3808.6492)  time: 1.0169  data: 0.0751  max mem: 15828
# Epoch: [0]  [40/98]  eta: 0:01:03  lr: 0.000100  class_error: 69.48  loss: 9.4169 (10.0212)  loss_ce: 1.3202 (1.2745)  loss_bbox: 0.2171 (0.2847)  loss_giou: 0.2978 (0.3707)  loss_ce_0: 1.2937 (1.2283)  loss_bbox_0: 0.2508 (0.3546)  loss_giou_0: 0.3385 (0.4464)  loss_ce_1: 1.3047 (1.2517)  loss_bbox_1: 0.2376 (0.3192)  loss_giou_1: 0.3198 (0.4079)  loss_ce_2: 1.3162 (1.2688)  loss_bbox_2: 0.2216 (0.2962)  loss_giou_2: 0.3043 (0.3832)  loss_ce_enc: 1.2535 (1.1892)  loss_bbox_enc: 0.3255 (0.4265)  loss_giou_enc: 0.4141 (0.5192)  loss_ce_unscaled: 1.3202 (1.2745)  class_error_unscaled: 81.2937 (87.7852)  loss_bbox_unscaled: 0.0434 (0.0569)  loss_giou_unscaled: 0.1489 (0.1854)  cardinality_error_unscaled: 3863.0625 (3846.0244)  loss_ce_0_unscaled: 1.2937 (1.2283)  loss_bbox_0_unscaled: 0.0502 (0.0709)  loss_giou_0_unscaled: 0.1693 (0.2232)  cardinality_error_0_unscaled: 3834.3750 (3831.3841)  loss_ce_1_unscaled: 1.3047 (1.2517)  loss_bbox_1_unscaled: 0.0475 (0.0638)  loss_giou_1_unscaled: 0.1599 (0.2040)  cardinality_error_1_unscaled: 3645.0000 (3597.7134)  loss_ce_2_unscaled: 1.3162 (1.2688)  loss_bbox_2_unscaled: 0.0443 (0.0592)  loss_giou_2_unscaled: 0.1521 (0.1916)  cardinality_error_2_unscaled: 3865.2500 (3840.6966)  loss_ce_enc_unscaled: 1.2535 (1.1892)  loss_bbox_enc_unscaled: 0.0651 (0.0853)  loss_giou_enc_unscaled: 0.2070 (0.2596)  cardinality_error_enc_unscaled: 3700.2500 (3767.3979)  time: 1.0333  data: 0.0790  max mem: 15828
# Epoch: [0]  [50/98]  eta: 0:00:51  lr: 0.000100  class_error: 64.94  loss: 9.2876 (9.9001)  loss_ce: 1.3225 (1.2853)  loss_bbox: 0.2121 (0.2725)  loss_giou: 0.2756 (0.3592)  loss_ce_0: 1.3097 (1.2442)  loss_bbox_0: 0.2259 (0.3303)  loss_giou_0: 0.2978 (0.4235)  loss_ce_1: 1.3155 (1.2644)  loss_bbox_1: 0.2243 (0.3019)  loss_giou_1: 0.2843 (0.3910)  loss_ce_2: 1.3279 (1.2800)  loss_bbox_2: 0.2153 (0.2818)  loss_giou_2: 0.2676 (0.3696)  loss_ce_enc: 1.2910 (1.2086)  loss_bbox_enc: 0.2675 (0.3962)  loss_giou_enc: 0.3452 (0.4916)  loss_ce_unscaled: 1.3225 (1.2853)  class_error_unscaled: 72.5275 (83.9843)  loss_bbox_unscaled: 0.0424 (0.0545)  loss_giou_unscaled: 0.1378 (0.1796)  cardinality_error_unscaled: 3874.6250 (3851.9645)  loss_ce_0_unscaled: 1.3097 (1.2442)  loss_bbox_0_unscaled: 0.0452 (0.0661)  loss_giou_0_unscaled: 0.1489 (0.2117)  cardinality_error_0_unscaled: 3856.8750 (3838.3100)  loss_ce_1_unscaled: 1.3155 (1.2644)  loss_bbox_1_unscaled: 0.0449 (0.0604)  loss_giou_1_unscaled: 0.1421 (0.1955)  cardinality_error_1_unscaled: 3743.4375 (3628.4387)  loss_ce_2_unscaled: 1.3279 (1.2800)  loss_bbox_2_unscaled: 0.0431 (0.0564)  loss_giou_2_unscaled: 0.1338 (0.1848)  cardinality_error_2_unscaled: 3875.2500 (3847.8775)  loss_ce_enc_unscaled: 1.2910 (1.2086)  loss_bbox_enc_unscaled: 0.0535 (0.0792)  loss_giou_enc_unscaled: 0.1726 (0.2458)  cardinality_error_enc_unscaled: 3600.5625 (3727.2966)  time: 1.0333  data: 0.0789  max mem: 15828
# Epoch: [0]  [60/98]  eta: 0:00:40  lr: 0.000100  class_error: 54.07  loss: 9.2599 (9.7992)  loss_ce: 1.3418 (1.3013)  loss_bbox: 0.2120 (0.2632)  loss_giou: 0.2756 (0.3432)  loss_ce_0: 1.3372 (1.2622)  loss_bbox_0: 0.2137 (0.3113)  loss_giou_0: 0.2751 (0.3978)  loss_ce_1: 1.3365 (1.2800)  loss_bbox_1: 0.2168 (0.2878)  loss_giou_1: 0.2755 (0.3704)  loss_ce_2: 1.3451 (1.2940)  loss_bbox_2: 0.2122 (0.2715)  loss_giou_2: 0.2687 (0.3528)  loss_ce_enc: 1.3233 (1.2307)  loss_bbox_enc: 0.2549 (0.3724)  loss_giou_enc: 0.3055 (0.4606)  loss_ce_unscaled: 1.3418 (1.3013)  class_error_unscaled: 64.1509 (80.1001)  loss_bbox_unscaled: 0.0424 (0.0526)  loss_giou_unscaled: 0.1378 (0.1716)  cardinality_error_unscaled: 3870.8125 (3840.2643)  loss_ce_0_unscaled: 1.3372 (1.2622)  loss_bbox_0_unscaled: 0.0427 (0.0623)  loss_giou_0_unscaled: 0.1375 (0.1989)  cardinality_error_0_unscaled: 3856.6250 (3839.2572)  loss_ce_1_unscaled: 1.3365 (1.2800)  loss_bbox_1_unscaled: 0.0434 (0.0576)  loss_giou_1_unscaled: 0.1377 (0.1852)  cardinality_error_1_unscaled: 3743.4375 (3640.4139)  loss_ce_2_unscaled: 1.3451 (1.2940)  loss_bbox_2_unscaled: 0.0424 (0.0543)  loss_giou_2_unscaled: 0.1344 (0.1764)  cardinality_error_2_unscaled: 3870.3125 (3846.3484)  loss_ce_enc_unscaled: 1.3233 (1.2307)  loss_bbox_enc_unscaled: 0.0510 (0.0745)  loss_giou_enc_unscaled: 0.1528 (0.2303)  cardinality_error_enc_unscaled: 3523.6875 (3690.4846)  time: 0.9954  data: 0.0752  max mem: 15828
# Epoch: [0]  [70/98]  eta: 0:00:29  lr: 0.000100  class_error: 50.68  loss: 9.2460 (9.7219)  loss_ce: 1.3664 (1.3096)  loss_bbox: 0.2120 (0.2581)  loss_giou: 0.2516 (0.3308)  loss_ce_0: 1.3564 (1.2782)  loss_bbox_0: 0.2131 (0.2961)  loss_giou_0: 0.2565 (0.3757)  loss_ce_1: 1.3576 (1.2938)  loss_bbox_1: 0.2098 (0.2778)  loss_giou_1: 0.2486 (0.3534)  loss_ce_2: 1.3458 (1.3042)  loss_bbox_2: 0.2155 (0.2653)  loss_giou_2: 0.2657 (0.3394)  loss_ce_enc: 1.3564 (1.2508)  loss_bbox_enc: 0.2416 (0.3540)  loss_giou_enc: 0.2778 (0.4347)  loss_ce_unscaled: 1.3664 (1.3096)  class_error_unscaled: 52.3077 (75.2881)  loss_bbox_unscaled: 0.0424 (0.0516)  loss_giou_unscaled: 0.1258 (0.1654)  cardinality_error_unscaled: 3695.0000 (3813.5097)  loss_ce_0_unscaled: 1.3564 (1.2782)  loss_bbox_0_unscaled: 0.0426 (0.0592)  loss_giou_0_unscaled: 0.1282 (0.1879)  cardinality_error_0_unscaled: 3818.2500 (3830.1382)  loss_ce_1_unscaled: 1.3576 (1.2938)  loss_bbox_1_unscaled: 0.0420 (0.0556)  loss_giou_1_unscaled: 0.1243 (0.1767)  cardinality_error_1_unscaled: 3710.9375 (3648.1250)  loss_ce_2_unscaled: 1.3458 (1.3042)  loss_bbox_2_unscaled: 0.0431 (0.0531)  loss_giou_2_unscaled: 0.1329 (0.1697)  cardinality_error_2_unscaled: 3817.6875 (3838.1303)  loss_ce_enc_unscaled: 1.3564 (1.2508)  loss_bbox_enc_unscaled: 0.0483 (0.0708)  loss_giou_enc_unscaled: 0.1389 (0.2173)  cardinality_error_enc_unscaled: 3508.5625 (3663.5845)  time: 1.0083  data: 0.0760  max mem: 15828
# Epoch: [0]  [80/98]  eta: 0:00:18  lr: 0.000100  class_error: 31.48  loss: 9.1843 (9.6443)  loss_ce: 1.3215 (1.3068)  loss_bbox: 0.2276 (0.2541)  loss_giou: 0.2483 (0.3224)  loss_ce_0: 1.3693 (1.2887)  loss_bbox_0: 0.2000 (0.2842)  loss_giou_0: 0.2375 (0.3599)  loss_ce_1: 1.3672 (1.3016)  loss_bbox_1: 0.2141 (0.2698)  loss_giou_1: 0.2420 (0.3414)  loss_ce_2: 1.3324 (1.3055)  loss_bbox_2: 0.2269 (0.2604)  loss_giou_2: 0.2535 (0.3301)  loss_ce_enc: 1.3770 (1.2666)  loss_bbox_enc: 0.2307 (0.3383)  loss_giou_enc: 0.2599 (0.4144)  loss_ce_unscaled: 1.3215 (1.3068)  class_error_unscaled: 36.1538 (69.4759)  loss_bbox_unscaled: 0.0455 (0.0508)  loss_giou_unscaled: 0.1241 (0.1612)  cardinality_error_unscaled: 3695.0000 (3808.0000)  loss_ce_0_unscaled: 1.3693 (1.2887)  loss_bbox_0_unscaled: 0.0400 (0.0568)  loss_giou_0_unscaled: 0.1188 (0.1799)  cardinality_error_0_unscaled: 3786.2500 (3827.2955)  loss_ce_1_unscaled: 1.3672 (1.3016)  loss_bbox_1_unscaled: 0.0428 (0.0540)  loss_giou_1_unscaled: 0.1210 (0.1707)  cardinality_error_1_unscaled: 3738.5625 (3665.1057)  loss_ce_2_unscaled: 1.3324 (1.3055)  loss_bbox_2_unscaled: 0.0454 (0.0521)  loss_giou_2_unscaled: 0.1268 (0.1651)  cardinality_error_2_unscaled: 3819.3750 (3836.3380)  loss_ce_enc_unscaled: 1.3770 (1.2666)  loss_bbox_enc_unscaled: 0.0461 (0.0677)  loss_giou_enc_unscaled: 0.1299 (0.2072)  cardinality_error_enc_unscaled: 3541.7500 (3654.9252)  time: 1.0060  data: 0.0762  max mem: 15828
# Epoch: [0]  [90/98]  eta: 0:00:08  lr: 0.000100  class_error: 30.77  loss: 9.0419 (9.5695)  loss_ce: 1.2522 (1.2963)  loss_bbox: 0.2269 (0.2501)  loss_giou: 0.2880 (0.3217)  loss_ce_0: 1.3446 (1.2924)  loss_bbox_0: 0.1985 (0.2738)  loss_giou_0: 0.2697 (0.3524)  loss_ce_1: 1.3278 (1.3021)  loss_bbox_1: 0.2124 (0.2616)  loss_giou_1: 0.2708 (0.3362)  loss_ce_2: 1.2771 (1.2985)  loss_bbox_2: 0.2178 (0.2547)  loss_giou_2: 0.2877 (0.3280)  loss_ce_enc: 1.3579 (1.2751)  loss_bbox_enc: 0.2089 (0.3237)  loss_giou_enc: 0.2929 (0.4030)  loss_ce_unscaled: 1.2522 (1.2963)  class_error_unscaled: 30.7692 (65.3091)  loss_bbox_unscaled: 0.0454 (0.0500)  loss_giou_unscaled: 0.1440 (0.1609)  cardinality_error_unscaled: 3737.8125 (3796.7960)  loss_ce_0_unscaled: 1.3446 (1.2924)  loss_bbox_0_unscaled: 0.0397 (0.0548)  loss_giou_0_unscaled: 0.1349 (0.1762)  cardinality_error_0_unscaled: 3812.6250 (3824.5275)  loss_ce_1_unscaled: 1.3278 (1.3021)  loss_bbox_1_unscaled: 0.0425 (0.0523)  loss_giou_1_unscaled: 0.1354 (0.1681)  cardinality_error_1_unscaled: 3769.7500 (3672.2459)  loss_ce_2_unscaled: 1.2771 (1.2985)  loss_bbox_2_unscaled: 0.0436 (0.0509)  loss_giou_2_unscaled: 0.1438 (0.1640)  cardinality_error_2_unscaled: 3833.1250 (3831.8750)  loss_ce_enc_unscaled: 1.3579 (1.2751)  loss_bbox_enc_unscaled: 0.0418 (0.0647)  loss_giou_enc_unscaled: 0.1465 (0.2015)  cardinality_error_enc_unscaled: 3631.2500 (3655.5776)  time: 0.9896  data: 0.0785  max mem: 15828
# Epoch: [0]  [97/98]  eta: 0:00:01  lr: 0.000100  class_error: 23.35  loss: 8.9661 (9.5325)  loss_ce: 1.2284 (1.2913)  loss_bbox: 0.2247 (0.2500)  loss_giou: 0.2880 (0.3168)  loss_ce_0: 1.3446 (1.3000)  loss_bbox_0: 0.1846 (0.2683)  loss_giou_0: 0.2697 (0.3424)  loss_ce_1: 1.3278 (1.3087)  loss_bbox_1: 0.1955 (0.2581)  loss_giou_1: 0.2708 (0.3283)  loss_ce_2: 1.2771 (1.2980)  loss_bbox_2: 0.2138 (0.2540)  loss_giou_2: 0.2877 (0.3223)  loss_ce_enc: 1.3609 (1.2861)  loss_bbox_enc: 0.2089 (0.3170)  loss_giou_enc: 0.2870 (0.3912)  loss_ce_unscaled: 1.2284 (1.2913)  class_error_unscaled: 28.9941 (62.2227)  loss_bbox_unscaled: 0.0449 (0.0500)  loss_giou_unscaled: 0.1440 (0.1584)  cardinality_error_unscaled: 3726.1875 (3788.1173)  loss_ce_0_unscaled: 1.3446 (1.3000)  loss_bbox_0_unscaled: 0.0369 (0.0537)  loss_giou_0_unscaled: 0.1349 (0.1712)  cardinality_error_0_unscaled: 3798.8125 (3820.1046)  loss_ce_1_unscaled: 1.3278 (1.3087)  loss_bbox_1_unscaled: 0.0391 (0.0516)  loss_giou_1_unscaled: 0.1354 (0.1642)  cardinality_error_1_unscaled: 3722.0625 (3671.8170)  loss_ce_2_unscaled: 1.2771 (1.2980)  loss_bbox_2_unscaled: 0.0428 (0.0508)  loss_giou_2_unscaled: 0.1438 (0.1612)  cardinality_error_2_unscaled: 3809.5000 (3828.2124)  loss_ce_enc_unscaled: 1.3609 (1.2861)  loss_bbox_enc_unscaled: 0.0418 (0.0634)  loss_giou_enc_unscaled: 0.1435 (0.1956)  cardinality_error_enc_unscaled: 3661.6875 (3655.1448)  time: 1.0101  data: 0.1079  max mem: 15828
# Epoch: [0] Total time: 0:01:42 (1.0478 s / it)
# Averaged stats: lr: 0.000100  class_error: 23.35  loss: 8.9661 (9.5325)  loss_ce: 1.2284 (1.2913)  loss_bbox: 0.2247 (0.2500)  loss_giou: 0.2880 (0.3168)  loss_ce_0: 1.3446 (1.3000)  loss_bbox_0: 0.1846 (0.2683)  loss_giou_0: 0.2697 (0.3424)  loss_ce_1: 1.3278 (1.3087)  loss_bbox_1: 0.1955 (0.2581)  loss_giou_1: 0.2708 (0.3283)  loss_ce_2: 1.2771 (1.2980)  loss_bbox_2: 0.2138 (0.2540)  loss_giou_2: 0.2877 (0.3223)  loss_ce_enc: 1.3609 (1.2861)  loss_bbox_enc: 0.2089 (0.3170)  loss_giou_enc: 0.2870 (0.3912)  loss_ce_unscaled: 1.2284 (1.2913)  class_error_unscaled: 28.9941 (62.2227)  loss_bbox_unscaled: 0.0449 (0.0500)  loss_giou_unscaled: 0.1440 (0.1584)  cardinality_error_unscaled: 3726.1875 (3788.1173)  loss_ce_0_unscaled: 1.3446 (1.3000)  loss_bbox_0_unscaled: 0.0369 (0.0537)  loss_giou_0_unscaled: 0.1349 (0.1712)  cardinality_error_0_unscaled: 3798.8125 (3820.1046)  loss_ce_1_unscaled: 1.3278 (1.3087)  loss_bbox_1_unscaled: 0.0391 (0.0516)  loss_giou_1_unscaled: 0.1354 (0.1642)  cardinality_error_1_unscaled: 3722.0625 (3671.8170)  loss_ce_2_unscaled: 1.2771 (1.2980)  loss_bbox_2_unscaled: 0.0428 (0.0508)  loss_giou_2_unscaled: 0.1438 (0.1612)  cardinality_error_2_unscaled: 3809.5000 (3828.2124)  loss_ce_enc_unscaled: 1.3609 (1.2861)  loss_bbox_enc_unscaled: 0.0418 (0.0634)  loss_giou_enc_unscaled: 0.1435 (0.1956)  cardinality_error_enc_unscaled: 3661.6875 (3655.1448)
# Test:  [ 0/57]  eta: 0:00:52  class_error: 23.64  loss: 8.4444 (8.4444)  loss_ce: 1.1172 (1.1172)  loss_bbox: 0.1777 (0.1777)  loss_giou: 0.3018 (0.3018)  loss_ce_0: 1.3359 (1.3359)  loss_bbox_0: 0.1311 (0.1311)  loss_giou_0: 0.2414 (0.2414)  loss_ce_1: 1.2812 (1.2812)  loss_bbox_1: 0.1543 (0.1543)  loss_giou_1: 0.2561 (0.2561)  loss_ce_2: 1.2031 (1.2031)  loss_bbox_2: 0.1707 (0.1707)  loss_giou_2: 0.2881 (0.2881)  loss_ce_enc: 1.3672 (1.3672)  loss_bbox_enc: 0.1537 (0.1537)  loss_giou_enc: 0.2648 (0.2648)  loss_ce_unscaled: 1.1172 (1.1172)  class_error_unscaled: 23.6364 (23.6364)  loss_bbox_unscaled: 0.0355 (0.0355)  loss_giou_unscaled: 0.1509 (0.1509)  cardinality_error_unscaled: 285.9375 (285.9375)  loss_ce_0_unscaled: 1.3359 (1.3359)  loss_bbox_0_unscaled: 0.0262 (0.0262)  loss_giou_0_unscaled: 0.1207 (0.1207)  cardinality_error_0_unscaled: 289.3125 (289.3125)  loss_ce_1_unscaled: 1.2812 (1.2812)  loss_bbox_1_unscaled: 0.0309 (0.0309)  loss_giou_1_unscaled: 0.1281 (0.1281)  cardinality_error_1_unscaled: 283.0000 (283.0000)  loss_ce_2_unscaled: 1.2031 (1.2031)  loss_bbox_2_unscaled: 0.0341 (0.0341)  loss_giou_2_unscaled: 0.1441 (0.1441)  cardinality_error_2_unscaled: 288.4375 (288.4375)  loss_ce_enc_unscaled: 1.3672 (1.3672)  loss_bbox_enc_unscaled: 0.0307 (0.0307)  loss_giou_enc_unscaled: 0.1324 (0.1324)  cardinality_error_enc_unscaled: 296.5625 (296.5625)  time: 0.9128  data: 0.6233  max mem: 15828
# Test:  [10/57]  eta: 0:00:18  class_error: 17.46  loss: 8.5861 (8.6035)  loss_ce: 1.1172 (1.1307)  loss_bbox: 0.2005 (0.2094)  loss_giou: 0.2804 (0.2823)  loss_ce_0: 1.3359 (1.3452)  loss_bbox_0: 0.1635 (0.1603)  loss_giou_0: 0.2414 (0.2378)  loss_ce_1: 1.3047 (1.3089)  loss_bbox_1: 0.1725 (0.1725)  loss_giou_1: 0.2505 (0.2477)  loss_ce_2: 1.1875 (1.1953)  loss_bbox_2: 0.2123 (0.2086)  loss_giou_2: 0.2827 (0.2769)  loss_ce_enc: 1.3828 (1.3849)  loss_bbox_enc: 0.1781 (0.1815)  loss_giou_enc: 0.2690 (0.2615)  loss_ce_unscaled: 1.1172 (1.1307)  class_error_unscaled: 22.9167 (20.3713)  loss_bbox_unscaled: 0.0401 (0.0419)  loss_giou_unscaled: 0.1402 (0.1412)  cardinality_error_unscaled: 285.0625 (283.2330)  loss_ce_0_unscaled: 1.3359 (1.3452)  loss_bbox_0_unscaled: 0.0327 (0.0321)  loss_giou_0_unscaled: 0.1207 (0.1189)  cardinality_error_0_unscaled: 285.2500 (282.6989)  loss_ce_1_unscaled: 1.3047 (1.3089)  loss_bbox_1_unscaled: 0.0345 (0.0345)  loss_giou_1_unscaled: 0.1253 (0.1239)  cardinality_error_1_unscaled: 282.8125 (279.6761)  loss_ce_2_unscaled: 1.1875 (1.1953)  loss_bbox_2_unscaled: 0.0425 (0.0417)  loss_giou_2_unscaled: 0.1414 (0.1384)  cardinality_error_2_unscaled: 289.0625 (288.8807)  loss_ce_enc_unscaled: 1.3828 (1.3849)  loss_bbox_enc_unscaled: 0.0356 (0.0363)  loss_giou_enc_unscaled: 0.1345 (0.1308)  cardinality_error_enc_unscaled: 297.0625 (296.9716)  time: 0.4001  data: 0.1040  max mem: 15828
# Test:  [20/57]  eta: 0:00:13  class_error: 10.00  loss: 8.6026 (8.5839)  loss_ce: 1.1172 (1.1220)  loss_bbox: 0.2005 (0.2056)  loss_giou: 0.2814 (0.2894)  loss_ce_0: 1.3359 (1.3367)  loss_bbox_0: 0.1608 (0.1587)  loss_giou_0: 0.2516 (0.2470)  loss_ce_1: 1.3047 (1.3017)  loss_bbox_1: 0.1725 (0.1705)  loss_giou_1: 0.2557 (0.2564)  loss_ce_2: 1.1875 (1.1890)  loss_bbox_2: 0.2054 (0.2014)  loss_giou_2: 0.2792 (0.2826)  loss_ce_enc: 1.3828 (1.3795)  loss_bbox_enc: 0.1750 (0.1764)  loss_giou_enc: 0.2690 (0.2671)  loss_ce_unscaled: 1.1172 (1.1220)  class_error_unscaled: 20.6897 (19.8078)  loss_bbox_unscaled: 0.0401 (0.0411)  loss_giou_unscaled: 0.1407 (0.1447)  cardinality_error_unscaled: 283.8750 (282.5714)  loss_ce_0_unscaled: 1.3359 (1.3367)  loss_bbox_0_unscaled: 0.0322 (0.0317)  loss_giou_0_unscaled: 0.1258 (0.1235)  cardinality_error_0_unscaled: 284.5625 (281.7321)  loss_ce_1_unscaled: 1.3047 (1.3017)  loss_bbox_1_unscaled: 0.0345 (0.0341)  loss_giou_1_unscaled: 0.1278 (0.1282)  cardinality_error_1_unscaled: 280.8750 (279.3750)  loss_ce_2_unscaled: 1.1875 (1.1890)  loss_bbox_2_unscaled: 0.0411 (0.0403)  loss_giou_2_unscaled: 0.1396 (0.1413)  cardinality_error_2_unscaled: 289.0625 (288.7738)  loss_ce_enc_unscaled: 1.3828 (1.3795)  loss_bbox_enc_unscaled: 0.0350 (0.0353)  loss_giou_enc_unscaled: 0.1345 (0.1335)  cardinality_error_enc_unscaled: 297.0625 (296.8452)  time: 0.3411  data: 0.0503  max mem: 15828
# Test:  [30/57]  eta: 0:00:09  class_error: 20.69  loss: 8.5743 (8.5906)  loss_ce: 1.1016 (1.1184)  loss_bbox: 0.2152 (0.2095)  loss_giou: 0.2821 (0.2875)  loss_ce_0: 1.3359 (1.3397)  loss_bbox_0: 0.1553 (0.1609)  loss_giou_0: 0.2500 (0.2444)  loss_ce_1: 1.3047 (1.3007)  loss_bbox_1: 0.1760 (0.1765)  loss_giou_1: 0.2611 (0.2561)  loss_ce_2: 1.1797 (1.1867)  loss_bbox_2: 0.1970 (0.2057)  loss_giou_2: 0.2788 (0.2809)  loss_ce_enc: 1.3906 (1.3818)  loss_bbox_enc: 0.1679 (0.1774)  loss_giou_enc: 0.2577 (0.2644)  loss_ce_unscaled: 1.1016 (1.1184)  class_error_unscaled: 20.6897 (19.5080)  loss_bbox_unscaled: 0.0430 (0.0419)  loss_giou_unscaled: 0.1411 (0.1438)  cardinality_error_unscaled: 283.9375 (282.4435)  loss_ce_0_unscaled: 1.3359 (1.3397)  loss_bbox_0_unscaled: 0.0311 (0.0322)  loss_giou_0_unscaled: 0.1250 (0.1222)  cardinality_error_0_unscaled: 284.5625 (281.9879)  loss_ce_1_unscaled: 1.3047 (1.3007)  loss_bbox_1_unscaled: 0.0352 (0.0353)  loss_giou_1_unscaled: 0.1306 (0.1281)  cardinality_error_1_unscaled: 280.8750 (279.5504)  loss_ce_2_unscaled: 1.1797 (1.1867)  loss_bbox_2_unscaled: 0.0394 (0.0411)  loss_giou_2_unscaled: 0.1394 (0.1404)  cardinality_error_2_unscaled: 290.8125 (288.9637)  loss_ce_enc_unscaled: 1.3906 (1.3818)  loss_bbox_enc_unscaled: 0.0336 (0.0355)  loss_giou_enc_unscaled: 0.1289 (0.1322)  cardinality_error_enc_unscaled: 297.1250 (296.8569)  time: 0.3329  data: 0.0482  max mem: 15828
# Test:  [40/57]  eta: 0:00:05  class_error: 27.27  loss: 8.5743 (8.6115)  loss_ce: 1.1016 (1.1197)  loss_bbox: 0.2177 (0.2142)  loss_giou: 0.2801 (0.2859)  loss_ce_0: 1.3359 (1.3445)  loss_bbox_0: 0.1612 (0.1633)  loss_giou_0: 0.2294 (0.2407)  loss_ce_1: 1.3047 (1.3079)  loss_bbox_1: 0.1827 (0.1786)  loss_giou_1: 0.2486 (0.2524)  loss_ce_2: 1.1797 (1.1909)  loss_bbox_2: 0.2083 (0.2090)  loss_giou_2: 0.2776 (0.2777)  loss_ce_enc: 1.3906 (1.3887)  loss_bbox_enc: 0.1679 (0.1790)  loss_giou_enc: 0.2464 (0.2588)  loss_ce_unscaled: 1.1016 (1.1197)  class_error_unscaled: 19.3548 (19.4549)  loss_bbox_unscaled: 0.0435 (0.0428)  loss_giou_unscaled: 0.1400 (0.1430)  cardinality_error_unscaled: 283.9375 (282.8735)  loss_ce_0_unscaled: 1.3359 (1.3445)  loss_bbox_0_unscaled: 0.0322 (0.0327)  loss_giou_0_unscaled: 0.1147 (0.1203)  cardinality_error_0_unscaled: 283.8750 (282.4695)  loss_ce_1_unscaled: 1.3047 (1.3079)  loss_bbox_1_unscaled: 0.0365 (0.0357)  loss_giou_1_unscaled: 0.1243 (0.1262)  cardinality_error_1_unscaled: 282.8125 (280.4573)  loss_ce_2_unscaled: 1.1797 (1.1909)  loss_bbox_2_unscaled: 0.0417 (0.0418)  loss_giou_2_unscaled: 0.1388 (0.1388)  cardinality_error_2_unscaled: 292.3125 (289.4893)  loss_ce_enc_unscaled: 1.3906 (1.3887)  loss_bbox_enc_unscaled: 0.0336 (0.0358)  loss_giou_enc_unscaled: 0.1232 (0.1294)  cardinality_error_enc_unscaled: 297.1250 (296.9223)  time: 0.3345  data: 0.0482  max mem: 15828
# Test:  [50/57]  eta: 0:00:02  class_error: 25.93  loss: 8.6222 (8.6367)  loss_ce: 1.1172 (1.1238)  loss_bbox: 0.2178 (0.2173)  loss_giou: 0.2713 (0.2860)  loss_ce_0: 1.3359 (1.3453)  loss_bbox_0: 0.1616 (0.1660)  loss_giou_0: 0.2262 (0.2403)  loss_ce_1: 1.3047 (1.3099)  loss_bbox_1: 0.1868 (0.1814)  loss_giou_1: 0.2306 (0.2523)  loss_ce_2: 1.1953 (1.1933)  loss_bbox_2: 0.2111 (0.2130)  loss_giou_2: 0.2705 (0.2784)  loss_ce_enc: 1.3906 (1.3888)  loss_bbox_enc: 0.1831 (0.1817)  loss_giou_enc: 0.2401 (0.2593)  loss_ce_unscaled: 1.1172 (1.1238)  class_error_unscaled: 17.9487 (19.3301)  loss_bbox_unscaled: 0.0436 (0.0435)  loss_giou_unscaled: 0.1356 (0.1430)  cardinality_error_unscaled: 283.3125 (282.3713)  loss_ce_0_unscaled: 1.3359 (1.3453)  loss_bbox_0_unscaled: 0.0323 (0.0332)  loss_giou_0_unscaled: 0.1131 (0.1201)  cardinality_error_0_unscaled: 283.8750 (282.4804)  loss_ce_1_unscaled: 1.3047 (1.3099)  loss_bbox_1_unscaled: 0.0374 (0.0363)  loss_giou_1_unscaled: 0.1153 (0.1261)  cardinality_error_1_unscaled: 284.5625 (280.3015)  loss_ce_2_unscaled: 1.1953 (1.1933)  loss_bbox_2_unscaled: 0.0422 (0.0426)  loss_giou_2_unscaled: 0.1352 (0.1392)  cardinality_error_2_unscaled: 290.9375 (289.2953)  loss_ce_enc_unscaled: 1.3906 (1.3888)  loss_bbox_enc_unscaled: 0.0366 (0.0363)  loss_giou_enc_unscaled: 0.1200 (0.1296)  cardinality_error_enc_unscaled: 297.0625 (296.9559)  time: 0.3148  data: 0.0531  max mem: 15828
# Test:  [56/57]  eta: 0:00:00  class_error: 39.29  loss: 8.6222 (8.6221)  loss_ce: 1.1172 (1.1224)  loss_bbox: 0.2178 (0.2157)  loss_giou: 0.2857 (0.2868)  loss_ce_0: 1.3359 (1.3442)  loss_bbox_0: 0.1612 (0.1647)  loss_giou_0: 0.2321 (0.2404)  loss_ce_1: 1.3047 (1.3081)  loss_bbox_1: 0.1868 (0.1796)  loss_giou_1: 0.2447 (0.2524)  loss_ce_2: 1.1953 (1.1928)  loss_bbox_2: 0.2101 (0.2101)  loss_giou_2: 0.2747 (0.2783)  loss_ce_enc: 1.3906 (1.3871)  loss_bbox_enc: 0.1725 (0.1800)  loss_giou_enc: 0.2429 (0.2596)  loss_ce_unscaled: 1.1172 (1.1224)  class_error_unscaled: 19.3548 (19.7225)  loss_bbox_unscaled: 0.0436 (0.0431)  loss_giou_unscaled: 0.1429 (0.1434)  cardinality_error_unscaled: 280.4375 (282.4566)  loss_ce_0_unscaled: 1.3359 (1.3442)  loss_bbox_0_unscaled: 0.0322 (0.0329)  loss_giou_0_unscaled: 0.1160 (0.1202)  cardinality_error_0_unscaled: 281.5000 (282.4985)  loss_ce_1_unscaled: 1.3047 (1.3081)  loss_bbox_1_unscaled: 0.0374 (0.0359)  loss_giou_1_unscaled: 0.1223 (0.1262)  cardinality_error_1_unscaled: 282.8125 (280.4118)  loss_ce_2_unscaled: 1.1953 (1.1928)  loss_bbox_2_unscaled: 0.0420 (0.0420)  loss_giou_2_unscaled: 0.1373 (0.1391)  cardinality_error_2_unscaled: 290.4375 (289.2621)  loss_ce_enc_unscaled: 1.3906 (1.3871)  loss_bbox_enc_unscaled: 0.0345 (0.0360)  loss_giou_enc_unscaled: 0.1215 (0.1298)  cardinality_error_enc_unscaled: 297.0000 (296.9007)  time: 0.3343  data: 0.0528  max mem: 15828
# Test: Total time: 0:00:19 (0.3425 s / it)
# Averaged stats: class_error: 39.29  loss: 8.6222 (8.6221)  loss_ce: 1.1172 (1.1224)  loss_bbox: 0.2178 (0.2157)  loss_giou: 0.2857 (0.2868)  loss_ce_0: 1.3359 (1.3442)  loss_bbox_0: 0.1612 (0.1647)  loss_giou_0: 0.2321 (0.2404)  loss_ce_1: 1.3047 (1.3081)  loss_bbox_1: 0.1868 (0.1796)  loss_giou_1: 0.2447 (0.2524)  loss_ce_2: 1.1953 (1.1928)  loss_bbox_2: 0.2101 (0.2101)  loss_giou_2: 0.2747 (0.2783)  loss_ce_enc: 1.3906 (1.3871)  loss_bbox_enc: 0.1725 (0.1800)  loss_giou_enc: 0.2429 (0.2596)  loss_ce_unscaled: 1.1172 (1.1224)  class_error_unscaled: 19.3548 (19.7225)  loss_bbox_unscaled: 0.0436 (0.0431)  loss_giou_unscaled: 0.1429 (0.1434)  cardinality_error_unscaled: 280.4375 (282.4566)  loss_ce_0_unscaled: 1.3359 (1.3442)  loss_bbox_0_unscaled: 0.0322 (0.0329)  loss_giou_0_unscaled: 0.1160 (0.1202)  cardinality_error_0_unscaled: 281.5000 (282.4985)  loss_ce_1_unscaled: 1.3047 (1.3081)  loss_bbox_1_unscaled: 0.0374 (0.0359)  loss_giou_1_unscaled: 0.1223 (0.1262)  cardinality_error_1_unscaled: 282.8125 (280.4118)  loss_ce_2_unscaled: 1.1953 (1.1928)  loss_bbox_2_unscaled: 0.0420 (0.0420)  loss_giou_2_unscaled: 0.1373 (0.1391)  cardinality_error_2_unscaled: 290.4375 (289.2621)  loss_ce_enc_unscaled: 1.3906 (1.3871)  loss_bbox_enc_unscaled: 0.0345 (0.0360)  loss_giou_enc_unscaled: 0.1215 (0.1298)  cardinality_error_enc_unscaled: 297.0000 (296.9007)
# Accumulating evaluation results...
# DONE (t=2.90s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.347
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.504
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.410
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.430
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.302
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.373
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.480
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.720
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.757
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.588
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.633
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.784
# Test:  [ 0/57]  eta: 0:00:46  class_error: 23.64  loss: 8.5314 (8.5314)  loss_ce: 1.1328 (1.1328)  loss_bbox: 0.1774 (0.1774)  loss_giou: 0.3132 (0.3132)  loss_ce_0: 1.3203 (1.3203)  loss_bbox_0: 0.1506 (0.1506)  loss_giou_0: 0.2686 (0.2686)  loss_ce_1: 1.2812 (1.2812)  loss_bbox_1: 0.1552 (0.1552)  loss_giou_1: 0.2657 (0.2657)  loss_ce_2: 1.2031 (1.2031)  loss_bbox_2: 0.1802 (0.1802)  loss_giou_2: 0.3000 (0.3000)  loss_ce_enc: 1.3672 (1.3672)  loss_bbox_enc: 0.1495 (0.1495)  loss_giou_enc: 0.2663 (0.2663)  loss_ce_unscaled: 1.1328 (1.1328)  class_error_unscaled: 23.6364 (23.6364)  loss_bbox_unscaled: 0.0355 (0.0355)  loss_giou_unscaled: 0.1566 (0.1566)  cardinality_error_unscaled: 284.5625 (284.5625)  loss_ce_0_unscaled: 1.3203 (1.3203)  loss_bbox_0_unscaled: 0.0301 (0.0301)  loss_giou_0_unscaled: 0.1343 (0.1343)  cardinality_error_0_unscaled: 290.9375 (290.9375)  loss_ce_1_unscaled: 1.2812 (1.2812)  loss_bbox_1_unscaled: 0.0310 (0.0310)  loss_giou_1_unscaled: 0.1328 (0.1328)  cardinality_error_1_unscaled: 282.6875 (282.6875)  loss_ce_2_unscaled: 1.2031 (1.2031)  loss_bbox_2_unscaled: 0.0360 (0.0360)  loss_giou_2_unscaled: 0.1500 (0.1500)  cardinality_error_2_unscaled: 288.5625 (288.5625)  loss_ce_enc_unscaled: 1.3672 (1.3672)  loss_bbox_enc_unscaled: 0.0299 (0.0299)  loss_giou_enc_unscaled: 0.1332 (0.1332)  cardinality_error_enc_unscaled: 296.5625 (296.5625)  time: 0.8208  data: 0.5351  max mem: 15828
# Test:  [10/57]  eta: 0:00:19  class_error: 19.05  loss: 8.6765 (8.6487)  loss_ce: 1.1406 (1.1449)  loss_bbox: 0.2055 (0.2053)  loss_giou: 0.2913 (0.2863)  loss_ce_0: 1.3594 (1.3473)  loss_bbox_0: 0.1682 (0.1625)  loss_giou_0: 0.2335 (0.2418)  loss_ce_1: 1.3125 (1.3118)  loss_bbox_1: 0.1814 (0.1776)  loss_giou_1: 0.2507 (0.2579)  loss_ce_2: 1.2031 (1.2088)  loss_bbox_2: 0.1960 (0.2015)  loss_giou_2: 0.2786 (0.2797)  loss_ce_enc: 1.3828 (1.3864)  loss_bbox_enc: 0.1802 (0.1762)  loss_giou_enc: 0.2645 (0.2608)  loss_ce_unscaled: 1.1406 (1.1449)  class_error_unscaled: 19.0476 (18.7397)  loss_bbox_unscaled: 0.0411 (0.0411)  loss_giou_unscaled: 0.1456 (0.1432)  cardinality_error_unscaled: 284.5625 (282.8295)  loss_ce_0_unscaled: 1.3594 (1.3473)  loss_bbox_0_unscaled: 0.0336 (0.0325)  loss_giou_0_unscaled: 0.1167 (0.1209)  cardinality_error_0_unscaled: 286.9375 (283.6705)  loss_ce_1_unscaled: 1.3125 (1.3118)  loss_bbox_1_unscaled: 0.0363 (0.0355)  loss_giou_1_unscaled: 0.1254 (0.1289)  cardinality_error_1_unscaled: 282.3125 (279.3295)  loss_ce_2_unscaled: 1.2031 (1.2088)  loss_bbox_2_unscaled: 0.0392 (0.0403)  loss_giou_2_unscaled: 0.1393 (0.1398)  cardinality_error_2_unscaled: 288.5625 (288.1307)  loss_ce_enc_unscaled: 1.3828 (1.3864)  loss_bbox_enc_unscaled: 0.0360 (0.0352)  loss_giou_enc_unscaled: 0.1323 (0.1304)  cardinality_error_enc_unscaled: 297.0625 (296.9716)  time: 0.4134  data: 0.0949  max mem: 15828
# Test:  [20/57]  eta: 0:00:14  class_error: 10.00  loss: 8.6443 (8.6163)  loss_ce: 1.1328 (1.1388)  loss_bbox: 0.2048 (0.2002)  loss_giou: 0.2913 (0.2884)  loss_ce_0: 1.3281 (1.3389)  loss_bbox_0: 0.1624 (0.1596)  loss_giou_0: 0.2376 (0.2492)  loss_ce_1: 1.3047 (1.3039)  loss_bbox_1: 0.1707 (0.1745)  loss_giou_1: 0.2544 (0.2626)  loss_ce_2: 1.1953 (1.2001)  loss_bbox_2: 0.1936 (0.1986)  loss_giou_2: 0.2786 (0.2846)  loss_ce_enc: 1.3828 (1.3821)  loss_bbox_enc: 0.1703 (0.1701)  loss_giou_enc: 0.2597 (0.2647)  loss_ce_unscaled: 1.1328 (1.1388)  class_error_unscaled: 17.9487 (18.2176)  loss_bbox_unscaled: 0.0410 (0.0400)  loss_giou_unscaled: 0.1456 (0.1442)  cardinality_error_unscaled: 284.0000 (281.5089)  loss_ce_0_unscaled: 1.3281 (1.3389)  loss_bbox_0_unscaled: 0.0325 (0.0319)  loss_giou_0_unscaled: 0.1188 (0.1246)  cardinality_error_0_unscaled: 283.8125 (282.2827)  loss_ce_1_unscaled: 1.3047 (1.3039)  loss_bbox_1_unscaled: 0.0341 (0.0349)  loss_giou_1_unscaled: 0.1272 (0.1313)  cardinality_error_1_unscaled: 280.6875 (278.8065)  loss_ce_2_unscaled: 1.1953 (1.2001)  loss_bbox_2_unscaled: 0.0387 (0.0397)  loss_giou_2_unscaled: 0.1393 (0.1423)  cardinality_error_2_unscaled: 288.3125 (287.9524)  loss_ce_enc_unscaled: 1.3828 (1.3821)  loss_bbox_enc_unscaled: 0.0341 (0.0340)  loss_giou_enc_unscaled: 0.1298 (0.1323)  cardinality_error_enc_unscaled: 297.0625 (296.8452)  time: 0.3660  data: 0.0499  max mem: 15828
# Test:  [30/57]  eta: 0:00:09  class_error: 17.24  loss: 8.5997 (8.6243)  loss_ce: 1.1328 (1.1363)  loss_bbox: 0.2029 (0.2058)  loss_giou: 0.2850 (0.2860)  loss_ce_0: 1.3281 (1.3417)  loss_bbox_0: 0.1569 (0.1632)  loss_giou_0: 0.2491 (0.2469)  loss_ce_1: 1.3047 (1.3054)  loss_bbox_1: 0.1707 (0.1764)  loss_giou_1: 0.2561 (0.2588)  loss_ce_2: 1.1953 (1.1988)  loss_bbox_2: 0.1936 (0.2030)  loss_giou_2: 0.2814 (0.2826)  loss_ce_enc: 1.3906 (1.3841)  loss_bbox_enc: 0.1703 (0.1724)  loss_giou_enc: 0.2568 (0.2626)  loss_ce_unscaled: 1.1328 (1.1363)  class_error_unscaled: 17.9487 (18.6984)  loss_bbox_unscaled: 0.0406 (0.0412)  loss_giou_unscaled: 0.1425 (0.1430)  cardinality_error_unscaled: 283.5000 (281.3185)  loss_ce_0_unscaled: 1.3281 (1.3417)  loss_bbox_0_unscaled: 0.0314 (0.0326)  loss_giou_0_unscaled: 0.1246 (0.1235)  cardinality_error_0_unscaled: 283.1250 (282.4335)  loss_ce_1_unscaled: 1.3047 (1.3054)  loss_bbox_1_unscaled: 0.0341 (0.0353)  loss_giou_1_unscaled: 0.1280 (0.1294)  cardinality_error_1_unscaled: 280.6875 (278.9153)  loss_ce_2_unscaled: 1.1953 (1.1988)  loss_bbox_2_unscaled: 0.0387 (0.0406)  loss_giou_2_unscaled: 0.1407 (0.1413)  cardinality_error_2_unscaled: 289.8750 (288.0948)  loss_ce_enc_unscaled: 1.3906 (1.3841)  loss_bbox_enc_unscaled: 0.0341 (0.0345)  loss_giou_enc_unscaled: 0.1284 (0.1313)  cardinality_error_enc_unscaled: 297.1250 (296.8569)  time: 0.3295  data: 0.0487  max mem: 15828
# Test:  [40/57]  eta: 0:00:06  class_error: 21.21  loss: 8.5521 (8.6361)  loss_ce: 1.1172 (1.1370)  loss_bbox: 0.2169 (0.2110)  loss_giou: 0.2757 (0.2843)  loss_ce_0: 1.3438 (1.3481)  loss_bbox_0: 0.1679 (0.1633)  loss_giou_0: 0.2293 (0.2404)  loss_ce_1: 1.3125 (1.3123)  loss_bbox_1: 0.1719 (0.1785)  loss_giou_1: 0.2448 (0.2542)  loss_ce_2: 1.1953 (1.2048)  loss_bbox_2: 0.1936 (0.2041)  loss_giou_2: 0.2685 (0.2774)  loss_ce_enc: 1.3906 (1.3910)  loss_bbox_enc: 0.1709 (0.1739)  loss_giou_enc: 0.2458 (0.2557)  loss_ce_unscaled: 1.1172 (1.1370)  class_error_unscaled: 17.2414 (18.6140)  loss_bbox_unscaled: 0.0434 (0.0422)  loss_giou_unscaled: 0.1379 (0.1421)  cardinality_error_unscaled: 284.8125 (281.7378)  loss_ce_0_unscaled: 1.3438 (1.3481)  loss_bbox_0_unscaled: 0.0336 (0.0327)  loss_giou_0_unscaled: 0.1146 (0.1202)  cardinality_error_0_unscaled: 284.9375 (282.9466)  loss_ce_1_unscaled: 1.3125 (1.3123)  loss_bbox_1_unscaled: 0.0344 (0.0357)  loss_giou_1_unscaled: 0.1224 (0.1271)  cardinality_error_1_unscaled: 282.5000 (279.7530)  loss_ce_2_unscaled: 1.1953 (1.2048)  loss_bbox_2_unscaled: 0.0387 (0.0408)  loss_giou_2_unscaled: 0.1343 (0.1387)  cardinality_error_2_unscaled: 291.5625 (288.5991)  loss_ce_enc_unscaled: 1.3906 (1.3910)  loss_bbox_enc_unscaled: 0.0342 (0.0348)  loss_giou_enc_unscaled: 0.1229 (0.1279)  cardinality_error_enc_unscaled: 297.1250 (296.9223)  time: 0.3321  data: 0.0511  max mem: 15828
# Test:  [50/57]  eta: 0:00:02  class_error: 25.93  loss: 8.6801 (8.6554)  loss_ce: 1.1250 (1.1412)  loss_bbox: 0.2149 (0.2118)  loss_giou: 0.2686 (0.2831)  loss_ce_0: 1.3359 (1.3490)  loss_bbox_0: 0.1679 (0.1654)  loss_giou_0: 0.2177 (0.2400)  loss_ce_1: 1.3047 (1.3146)  loss_bbox_1: 0.1789 (0.1807)  loss_giou_1: 0.2386 (0.2542)  loss_ce_2: 1.2109 (1.2080)  loss_bbox_2: 0.1936 (0.2062)  loss_giou_2: 0.2662 (0.2770)  loss_ce_enc: 1.3906 (1.3908)  loss_bbox_enc: 0.1756 (0.1770)  loss_giou_enc: 0.2387 (0.2564)  loss_ce_unscaled: 1.1250 (1.1412)  class_error_unscaled: 16.1290 (18.6395)  loss_bbox_unscaled: 0.0430 (0.0424)  loss_giou_unscaled: 0.1343 (0.1415)  cardinality_error_unscaled: 283.0000 (281.3260)  loss_ce_0_unscaled: 1.3359 (1.3490)  loss_bbox_0_unscaled: 0.0336 (0.0331)  loss_giou_0_unscaled: 0.1088 (0.1200)  cardinality_error_0_unscaled: 284.9375 (283.0527)  loss_ce_1_unscaled: 1.3047 (1.3146)  loss_bbox_1_unscaled: 0.0358 (0.0361)  loss_giou_1_unscaled: 0.1193 (0.1271)  cardinality_error_1_unscaled: 283.2500 (279.6078)  loss_ce_2_unscaled: 1.2109 (1.2080)  loss_bbox_2_unscaled: 0.0387 (0.0412)  loss_giou_2_unscaled: 0.1331 (0.1385)  cardinality_error_2_unscaled: 291.1250 (288.4522)  loss_ce_enc_unscaled: 1.3906 (1.3908)  loss_bbox_enc_unscaled: 0.0351 (0.0354)  loss_giou_enc_unscaled: 0.1194 (0.1282)  cardinality_error_enc_unscaled: 297.0625 (296.9559)  time: 0.3619  data: 0.0519  max mem: 15828
# Test:  [56/57]  eta: 0:00:00  class_error: 42.86  loss: 8.5955 (8.6412)  loss_ce: 1.1328 (1.1404)  loss_bbox: 0.2077 (0.2097)  loss_giou: 0.2755 (0.2828)  loss_ce_0: 1.3359 (1.3479)  loss_bbox_0: 0.1689 (0.1639)  loss_giou_0: 0.2209 (0.2398)  loss_ce_1: 1.3047 (1.3130)  loss_bbox_1: 0.1789 (0.1790)  loss_giou_1: 0.2432 (0.2545)  loss_ce_2: 1.2109 (1.2071)  loss_bbox_2: 0.2037 (0.2046)  loss_giou_2: 0.2679 (0.2773)  loss_ce_enc: 1.3906 (1.3895)  loss_bbox_enc: 0.1756 (0.1754)  loss_giou_enc: 0.2387 (0.2564)  loss_ce_unscaled: 1.1328 (1.1404)  class_error_unscaled: 18.9655 (19.2997)  loss_bbox_unscaled: 0.0415 (0.0419)  loss_giou_unscaled: 0.1378 (0.1414)  cardinality_error_unscaled: 279.1250 (281.3787)  loss_ce_0_unscaled: 1.3359 (1.3479)  loss_bbox_0_unscaled: 0.0338 (0.0328)  loss_giou_0_unscaled: 0.1104 (0.1199)  cardinality_error_0_unscaled: 282.5000 (283.0654)  loss_ce_1_unscaled: 1.3047 (1.3130)  loss_bbox_1_unscaled: 0.0358 (0.0358)  loss_giou_1_unscaled: 0.1216 (0.1272)  cardinality_error_1_unscaled: 281.8125 (279.7110)  loss_ce_2_unscaled: 1.2109 (1.2071)  loss_bbox_2_unscaled: 0.0407 (0.0409)  loss_giou_2_unscaled: 0.1340 (0.1387)  cardinality_error_2_unscaled: 290.3750 (288.3923)  loss_ce_enc_unscaled: 1.3906 (1.3895)  loss_bbox_enc_unscaled: 0.0351 (0.0351)  loss_giou_enc_unscaled: 0.1194 (0.1282)  cardinality_error_enc_unscaled: 297.0000 (296.9007)  time: 0.3247  data: 0.0503  max mem: 15828
# Test: Total time: 0:00:20 (0.3530 s / it)
# Averaged stats: class_error: 42.86  loss: 8.5955 (8.6412)  loss_ce: 1.1328 (1.1404)  loss_bbox: 0.2077 (0.2097)  loss_giou: 0.2755 (0.2828)  loss_ce_0: 1.3359 (1.3479)  loss_bbox_0: 0.1689 (0.1639)  loss_giou_0: 0.2209 (0.2398)  loss_ce_1: 1.3047 (1.3130)  loss_bbox_1: 0.1789 (0.1790)  loss_giou_1: 0.2432 (0.2545)  loss_ce_2: 1.2109 (1.2071)  loss_bbox_2: 0.2037 (0.2046)  loss_giou_2: 0.2679 (0.2773)  loss_ce_enc: 1.3906 (1.3895)  loss_bbox_enc: 0.1756 (0.1754)  loss_giou_enc: 0.2387 (0.2564)  loss_ce_unscaled: 1.1328 (1.1404)  class_error_unscaled: 18.9655 (19.2997)  loss_bbox_unscaled: 0.0415 (0.0419)  loss_giou_unscaled: 0.1378 (0.1414)  cardinality_error_unscaled: 279.1250 (281.3787)  loss_ce_0_unscaled: 1.3359 (1.3479)  loss_bbox_0_unscaled: 0.0338 (0.0328)  loss_giou_0_unscaled: 0.1104 (0.1199)  cardinality_error_0_unscaled: 282.5000 (283.0654)  loss_ce_1_unscaled: 1.3047 (1.3130)  loss_bbox_1_unscaled: 0.0358 (0.0358)  loss_giou_1_unscaled: 0.1216 (0.1272)  cardinality_error_1_unscaled: 281.8125 (279.7110)  loss_ce_2_unscaled: 1.2109 (1.2071)  loss_bbox_2_unscaled: 0.0407 (0.0409)  loss_giou_2_unscaled: 0.1340 (0.1387)  cardinality_error_2_unscaled: 290.3750 (288.3923)  loss_ce_enc_unscaled: 1.3906 (1.3895)  loss_bbox_enc_unscaled: 0.0351 (0.0351)  loss_giou_enc_unscaled: 0.1194 (0.1282)  cardinality_error_enc_unscaled: 297.0000 (296.9007)
# Accumulating evaluation results...
# DONE (t=2.89s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.339
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.492
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.400
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.444
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.286
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.366
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.468
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.710
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.750
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.611
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.613
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.778
# Grad accum steps:  2
# Total batch size:  32
# LENGTH OF DATA LOADER: 98
# ...
# Test: Total time: 0:00:22 (0.3930 s / it)
# Averaged stats: class_error: 3.57  loss: 4.7786 (4.8245)  loss_ce: 0.4570 (0.4497)  loss_bbox: 0.2141 (0.2105)  loss_giou: 0.2669 (0.2714)  loss_ce_0: 0.4961 (0.4881)  loss_bbox_0: 0.2157 (0.2136)  loss_giou_0: 0.2730 (0.2749)  loss_ce_1: 0.4590 (0.4563)  loss_bbox_1: 0.2169 (0.2116)  loss_giou_1: 0.2670 (0.2726)  loss_ce_2: 0.4590 (0.4506)  loss_bbox_2: 0.2112 (0.2105)  loss_giou_2: 0.2672 (0.2717)  loss_ce_enc: 0.5078 (0.4991)  loss_bbox_enc: 0.2363 (0.2457)  loss_giou_enc: 0.2984 (0.2981)  loss_ce_unscaled: 0.4570 (0.4497)  class_error_unscaled: 0.0000 (0.4685)  loss_bbox_unscaled: 0.0428 (0.0421)  loss_giou_unscaled: 0.1335 (0.1357)  cardinality_error_unscaled: 274.1875 (274.5658)  loss_ce_0_unscaled: 0.4961 (0.4881)  loss_bbox_0_unscaled: 0.0431 (0.0427)  loss_giou_0_unscaled: 0.1365 (0.1374)  cardinality_error_0_unscaled: 291.4000 (290.4829)  loss_ce_1_unscaled: 0.4590 (0.4563)  loss_bbox_1_unscaled: 0.0434 (0.0423)  loss_giou_1_unscaled: 0.1335 (0.1363)  cardinality_error_1_unscaled: 292.5625 (292.2568)  loss_ce_2_unscaled: 0.4590 (0.4506)  loss_bbox_2_unscaled: 0.0422 (0.0421)  loss_giou_2_unscaled: 0.1336 (0.1359)  cardinality_error_2_unscaled: 290.2500 (288.8721)  loss_ce_enc_unscaled: 0.5078 (0.4991)  loss_bbox_enc_unscaled: 0.0473 (0.0491)  loss_giou_enc_unscaled: 0.1492 (0.1490)  cardinality_error_enc_unscaled: 291.6000 (287.6158)
# Accumulating evaluation results...
# DONE (t=3.65s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.745
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.985
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.909
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.491
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.630
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.769
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.636
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.805
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.549
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.715
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.824
# Training time 1:18:37
# Results saved to output/results.json
# Test:  [ 0/29]  eta: 0:00:31  class_error: 2.86  loss: 5.0394 (5.0394)  loss_ce: 0.5625 (0.5625)  loss_bbox: 0.1522 (0.1522)  loss_giou: 0.2662 (0.2662)  loss_ce_0: 0.5859 (0.5859)  loss_bbox_0: 0.1524 (0.1524)  loss_giou_0: 0.2680 (0.2680)  loss_ce_1: 0.5703 (0.5703)  loss_bbox_1: 0.1510 (0.1510)  loss_giou_1: 0.2648 (0.2648)  loss_ce_2: 0.5625 (0.5625)  loss_bbox_2: 0.1513 (0.1513)  loss_giou_2: 0.2649 (0.2649)  loss_ce_enc: 0.6016 (0.6016)  loss_bbox_enc: 0.1932 (0.1932)  loss_giou_enc: 0.2925 (0.2925)  loss_ce_unscaled: 0.5625 (0.5625)  class_error_unscaled: 2.8571 (2.8571)  loss_bbox_unscaled: 0.0304 (0.0304)  loss_giou_unscaled: 0.1331 (0.1331)  cardinality_error_unscaled: 278.8750 (278.8750)  loss_ce_0_unscaled: 0.5859 (0.5859)  loss_bbox_0_unscaled: 0.0305 (0.0305)  loss_giou_0_unscaled: 0.1340 (0.1340)  cardinality_error_0_unscaled: 292.3750 (292.3750)  loss_ce_1_unscaled: 0.5703 (0.5703)  loss_bbox_1_unscaled: 0.0302 (0.0302)  loss_giou_1_unscaled: 0.1324 (0.1324)  cardinality_error_1_unscaled: 293.7500 (293.7500)  loss_ce_2_unscaled: 0.5625 (0.5625)  loss_bbox_2_unscaled: 0.0303 (0.0303)  loss_giou_2_unscaled: 0.1324 (0.1324)  cardinality_error_2_unscaled: 291.9375 (291.9375)  loss_ce_enc_unscaled: 0.6016 (0.6016)  loss_bbox_enc_unscaled: 0.0386 (0.0386)  loss_giou_enc_unscaled: 0.1463 (0.1463)  cardinality_error_enc_unscaled: 292.7500 (292.7500)  time: 1.0950  data: 0.6605  max mem: 15880
# Test:  [10/29]  eta: 0:00:07  class_error: 0.00  loss: 4.8770 (4.9047)  loss_ce: 0.4707 (0.4778)  loss_bbox: 0.1922 (0.2063)  loss_giou: 0.2795 (0.2672)  loss_ce_0: 0.4902 (0.5147)  loss_bbox_0: 0.2040 (0.2099)  loss_giou_0: 0.2741 (0.2726)  loss_ce_1: 0.4609 (0.4771)  loss_bbox_1: 0.2008 (0.2084)  loss_giou_1: 0.2758 (0.2693)  loss_ce_2: 0.4590 (0.4703)  loss_bbox_2: 0.2018 (0.2076)  loss_giou_2: 0.2788 (0.2686)  loss_ce_enc: 0.4941 (0.5170)  loss_bbox_enc: 0.2338 (0.2420)  loss_giou_enc: 0.2925 (0.2958)  loss_ce_unscaled: 0.4707 (0.4778)  class_error_unscaled: 0.0000 (0.6199)  loss_bbox_unscaled: 0.0384 (0.0413)  loss_giou_unscaled: 0.1398 (0.1336)  cardinality_error_unscaled: 278.3125 (278.4034)  loss_ce_0_unscaled: 0.4902 (0.5147)  loss_bbox_0_unscaled: 0.0408 (0.0420)  loss_giou_0_unscaled: 0.1370 (0.1363)  cardinality_error_0_unscaled: 292.3750 (290.5568)  loss_ce_1_unscaled: 0.4609 (0.4771)  loss_bbox_1_unscaled: 0.0402 (0.0417)  loss_giou_1_unscaled: 0.1379 (0.1346)  cardinality_error_1_unscaled: 292.6875 (292.0341)  loss_ce_2_unscaled: 0.4590 (0.4703)  loss_bbox_2_unscaled: 0.0404 (0.0415)  loss_giou_2_unscaled: 0.1394 (0.1343)  cardinality_error_2_unscaled: 290.4375 (289.5568)  loss_ce_enc_unscaled: 0.4941 (0.5170)  loss_bbox_enc_unscaled: 0.0468 (0.0484)  loss_giou_enc_unscaled: 0.1463 (0.1479)  cardinality_error_enc_unscaled: 292.7500 (289.4943)  time: 0.4105  data: 0.1031  max mem: 15880
# Test:  [20/29]  eta: 0:00:03  class_error: 0.00  loss: 4.7735 (4.7877)  loss_ce: 0.4551 (0.4505)  loss_bbox: 0.1923 (0.2094)  loss_giou: 0.2452 (0.2623)  loss_ce_0: 0.4785 (0.4904)  loss_bbox_0: 0.2040 (0.2135)  loss_giou_0: 0.2521 (0.2673)  loss_ce_1: 0.4473 (0.4537)  loss_bbox_1: 0.2008 (0.2122)  loss_giou_1: 0.2474 (0.2642)  loss_ce_2: 0.4473 (0.4476)  loss_bbox_2: 0.2018 (0.2105)  loss_giou_2: 0.2456 (0.2630)  loss_ce_enc: 0.4902 (0.5012)  loss_bbox_enc: 0.2465 (0.2487)  loss_giou_enc: 0.2851 (0.2930)  loss_ce_unscaled: 0.4551 (0.4505)  class_error_unscaled: 0.0000 (0.5079)  loss_bbox_unscaled: 0.0385 (0.0419)  loss_giou_unscaled: 0.1226 (0.1312)  cardinality_error_unscaled: 278.3125 (278.8512)  loss_ce_0_unscaled: 0.4785 (0.4904)  loss_bbox_0_unscaled: 0.0408 (0.0427)  loss_giou_0_unscaled: 0.1260 (0.1337)  cardinality_error_0_unscaled: 293.1875 (291.6875)  loss_ce_1_unscaled: 0.4473 (0.4537)  loss_bbox_1_unscaled: 0.0402 (0.0424)  loss_giou_1_unscaled: 0.1237 (0.1321)  cardinality_error_1_unscaled: 294.3125 (292.8988)  loss_ce_2_unscaled: 0.4473 (0.4476)  loss_bbox_2_unscaled: 0.0404 (0.0421)  loss_giou_2_unscaled: 0.1228 (0.1315)  cardinality_error_2_unscaled: 291.0625 (290.4970)  loss_ce_enc_unscaled: 0.4902 (0.5012)  loss_bbox_enc_unscaled: 0.0493 (0.0497)  loss_giou_enc_unscaled: 0.1426 (0.1465)  cardinality_error_enc_unscaled: 292.7500 (290.3274)  time: 0.3831  data: 0.0484  max mem: 15880
# Test:  [28/29]  eta: 0:00:00  class_error: 0.00  loss: 4.8603 (4.8874)  loss_ce: 0.4336 (0.4594)  loss_bbox: 0.2234 (0.2172)  loss_giou: 0.2522 (0.2656)  loss_ce_0: 0.4785 (0.4987)  loss_bbox_0: 0.2227 (0.2198)  loss_giou_0: 0.2640 (0.2692)  loss_ce_1: 0.4355 (0.4623)  loss_bbox_1: 0.2204 (0.2199)  loss_giou_1: 0.2660 (0.2679)  loss_ce_2: 0.4297 (0.4561)  loss_bbox_2: 0.2243 (0.2184)  loss_giou_2: 0.2536 (0.2661)  loss_ce_enc: 0.5000 (0.5137)  loss_bbox_enc: 0.2640 (0.2564)  loss_giou_enc: 0.2929 (0.2966)  loss_ce_unscaled: 0.4336 (0.4594)  class_error_unscaled: 0.0000 (0.9528)  loss_bbox_unscaled: 0.0447 (0.0434)  loss_giou_unscaled: 0.1261 (0.1328)  cardinality_error_unscaled: 277.8125 (278.0754)  loss_ce_0_unscaled: 0.4785 (0.4987)  loss_bbox_0_unscaled: 0.0445 (0.0440)  loss_giou_0_unscaled: 0.1320 (0.1346)  cardinality_error_0_unscaled: 292.4375 (290.4591)  loss_ce_1_unscaled: 0.4355 (0.4623)  loss_bbox_1_unscaled: 0.0441 (0.0440)  loss_giou_1_unscaled: 0.1330 (0.1340)  cardinality_error_1_unscaled: 293.0625 (292.2737)  loss_ce_2_unscaled: 0.4297 (0.4561)  loss_bbox_2_unscaled: 0.0449 (0.0437)  loss_giou_2_unscaled: 0.1268 (0.1330)  cardinality_error_2_unscaled: 291.0625 (290.0086)  loss_ce_enc_unscaled: 0.5000 (0.5137)  loss_bbox_enc_unscaled: 0.0528 (0.0513)  loss_giou_enc_unscaled: 0.1465 (0.1483)  cardinality_error_enc_unscaled: 291.7500 (288.0517)  time: 0.3652  data: 0.0474  max mem: 15880
# Test: Total time: 0:00:11 (0.3877 s / it)
# Averaged stats: class_error: 0.00  loss: 4.8603 (4.8874)  loss_ce: 0.4336 (0.4594)  loss_bbox: 0.2234 (0.2172)  loss_giou: 0.2522 (0.2656)  loss_ce_0: 0.4785 (0.4987)  loss_bbox_0: 0.2227 (0.2198)  loss_giou_0: 0.2640 (0.2692)  loss_ce_1: 0.4355 (0.4623)  loss_bbox_1: 0.2204 (0.2199)  loss_giou_1: 0.2660 (0.2679)  loss_ce_2: 0.4297 (0.4561)  loss_bbox_2: 0.2243 (0.2184)  loss_giou_2: 0.2536 (0.2661)  loss_ce_enc: 0.5000 (0.5137)  loss_bbox_enc: 0.2640 (0.2564)  loss_giou_enc: 0.2929 (0.2966)  loss_ce_unscaled: 0.4336 (0.4594)  class_error_unscaled: 0.0000 (0.9528)  loss_bbox_unscaled: 0.0447 (0.0434)  loss_giou_unscaled: 0.1261 (0.1328)  cardinality_error_unscaled: 277.8125 (278.0754)  loss_ce_0_unscaled: 0.4785 (0.4987)  loss_bbox_0_unscaled: 0.0445 (0.0440)  loss_giou_0_unscaled: 0.1320 (0.1346)  cardinality_error_0_unscaled: 292.4375 (290.4591)  loss_ce_1_unscaled: 0.4355 (0.4623)  loss_bbox_1_unscaled: 0.0441 (0.0440)  loss_giou_1_unscaled: 0.1330 (0.1340)  cardinality_error_1_unscaled: 293.0625 (292.2737)  loss_ce_2_unscaled: 0.4297 (0.4561)  loss_bbox_2_unscaled: 0.0449 (0.0437)  loss_giou_2_unscaled: 0.1268 (0.1330)  cardinality_error_2_unscaled: 291.0625 (290.0086)  loss_ce_enc_unscaled: 0.5000 (0.5137)  loss_bbox_enc_unscaled: 0.0528 (0.0513)  loss_giou_enc_unscaled: 0.1465 (0.1483)  cardinality_error_enc_unscaled: 291.7500 (288.0517)
# Accumulating evaluation results...
# DONE (t=1.76s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.740
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.889
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.474
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.625
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.763
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.635
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.797
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.803
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.556
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.713
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.820
# Test results: {'class_error': 0.9528053546773976, 'loss': 4.887414882922995, 'loss_ce': 0.4593884698275862, 'loss_bbox': 0.21722060544737454, 'loss_giou': 0.2656066895558916, 'loss_ce_0': 0.49872036637931033, 'loss_bbox_0': 0.2197615658414775, 'loss_giou_0': 0.2692480945381625, 'loss_ce_1': 0.46228448275862066, 'loss_bbox_1': 0.21988407085681783, 'loss_giou_1': 0.2679199833294441, 'loss_ce_2': 0.4560883620689655, 'loss_bbox_2': 0.21844952013985863, 'loss_giou_2': 0.26609580732625104, 'loss_ce_enc': 0.513671875, 'loss_bbox_enc': 0.2564475736741362, 'loss_giou_enc': 0.29662735040845545, 'loss_ce_unscaled': 0.4593884698275862, 'class_error_unscaled': 0.9528053546773976, 'loss_bbox_unscaled': 0.04344412106378325, 'loss_giou_unscaled': 0.1328033447779458, 'cardinality_error_unscaled': 278.07543103448273, 'loss_ce_0_unscaled': 0.49872036637931033, 'loss_bbox_0_unscaled': 0.04395231296276224, 'loss_giou_0_unscaled': 0.13462404726908125, 'cardinality_error_0_unscaled': 290.4590517241379, 'loss_ce_1_unscaled': 0.46228448275862066, 'loss_bbox_1_unscaled': 0.04397681361899294, 'loss_giou_1_unscaled': 0.13395999166472206, 'cardinality_error_1_unscaled': 292.27370689655174, 'loss_ce_2_unscaled': 0.4560883620689655, 'loss_bbox_2_unscaled': 0.04368990402797173, 'loss_giou_2_unscaled': 0.13304790366312552, 'cardinality_error_2_unscaled': 290.0086206896552, 'loss_ce_enc_unscaled': 0.513671875, 'loss_bbox_enc_unscaled': 0.05128951486328553, 'loss_giou_enc_unscaled': 0.14831367520422772, 'cardinality_error_enc_unscaled': 288.05172413793105, 'results_json': {'class_map': [{'class': 'Analog_BPM', 'map@50:95': 0.8802068591474531, 'map@50': 1.0, 'precision': 1.0, 'recall': 0.96}, {'class': 'Analogue_Thermometer', 'map@50:95': 0.6378613833014217, 'map@50': 0.9819084517147365, 'precision': 0.8333333333333334, 'recall': 0.96}, {'class': 'Artery_Forcep', 'map@50:95': 0.7371578906315052, 'map@50': 0.9577366828174287, 'precision': 0.8450704225352113, 'recall': 0.96}, {'class': 'Cheatle_Forceps', 'map@50:95': 0.8647241689516101, 'map@50': 0.9922992299229921, 'precision': 0.8888888888888888, 'recall': 0.96}, {'class': 'Cotton', 'map@50:95': 0.5917059644338571, 'map@50': 0.9816706534485269, 'precision': 0.9444444444444444, 'recall': 0.96}, {'class': 'Digital_BPM', 'map@50:95': 0.8504737792922911, 'map@50': 1.0, 'precision': 1.0, 'recall': 0.96}, {'class': 'Digital_Thermometer', 'map@50:95': 0.7522689768976897, 'map@50': 1.0, 'precision': 1.0, 'recall': 0.96}, {'class': 'First_Aid_Box', 'map@50:95': 0.8788478477973948, 'map@50': 0.9996856828539997, 'precision': 1.0, 'recall': 0.96}, {'class': 'Foam_Roller', 'map@50:95': 0.793371231916349, 'map@50': 1.0, 'precision': 1.0, 'recall': 0.96}, {'class': 'Forceps_Jar', 'map@50:95': 0.6485532583842785, 'map@50': 0.9665723715228666, 'precision': 0.9777777777777777, 'recall': 0.96}, {'class': 'Galli_Pot', 'map@50:95': 0.7021701289785856, 'map@50': 0.9948727015558696, 'precision': 0.975, 'recall': 0.96}, {'class': 'Glucometer', 'map@50:95': 0.6832425922484643, 'map@50': 0.9949560993835233, 'precision': 1.0, 'recall': 0.96}, {'class': 'Hand_Gloves', 'map@50:95': 0.7745375892994274, 'map@50': 0.9597936994005308, 'precision': 0.9154929577464789, 'recall': 0.96}, {'class': 'Hexasol', 'map@50:95': 0.6176280692211753, 'map@50': 0.9331827919634067, 'precision': 0.8888888888888888, 'recall': 0.96}, {'class': 'Hot_water_Bag', 'map@50:95': 0.867037216231489, 'map@50': 0.9987998799879988, 'precision': 1.0, 'recall': 0.96}, {'class': 'Kidney_Tray', 'map@50:95': 0.8618853563136738, 'map@50': 1.0, 'precision': 1.0, 'recall': 0.96}, {'class': 'Neurological_Medical_Reflex_Hammer', 'map@50:95': 0.7662534059924867, 'map@50': 0.9649568260216341, 'precision': 0.9682539682539683, 'recall': 0.96}, {'class': 'One_Time_Bandage', 'map@50:95': 0.6471141600425011, 'map@50': 0.9135881850486076, 'precision': 0.7555555555555555, 'recall': 0.96}, {'class': 'Oral_Rehydration_Salt', 'map@50:95': 0.8143429727588144, 'map@50': 1.0, 'precision': 1.0, 'rec ...
# Results saved to output/metrics_plot.png

# %%
from PIL import Image

Image.open("/content/output/metrics_plot.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1800x1200>

# %%
# --- Confusion Matrix for RF-DETR on COCO test split ---
import supervision as sv
import numpy as np

# thresholds you can tune
CONF_THRESHOLD = 0.25   # ignore low-confidence preds
IOU_THRESHOLD  = 0.50   # match preds to GT by IoU >= 0.5

# callback that returns sv.Detections for a given image
def _predict_detections(image: np.ndarray) -> sv.Detections:
    """
    Works with both RF-DETR local (.predict) and Inference API (.infer) styles.
    - model.predict(...) -> returns sv.Detections directly
    - model.infer(...)[0] -> wrap with sv.Detections.from_inference(...)
    """
    try:
        # local RF-DETR API (recommended after fine-tuning)
        # returns sv.Detections with .xyxy, .confidence, .class_id
        return model.predict(image, threshold=CONF_THRESHOLD)
    except AttributeError:
        # Inference engine style (pred object needs wrapping)
        pred = model.infer(image, confidence=CONF_THRESHOLD)[0]
        return sv.Detections.from_inference(pred)

# build confusion matrix by benchmarking the whole dataset via callback
cm = sv.ConfusionMatrix.benchmark(
    dataset=ds,
    callback=_predict_detections,
    conf_threshold=CONF_THRESHOLD,
    iou_threshold=IOU_THRESHOLD,
)

# plot + save (normalized to percentages; change normalize=False for raw counts)
fig = cm.plot(
    title=f"Confusion Matrix",
    normalize=True,
    save_path="/content/output/confusion_matrix.png"
)

# If you're in a notebook and want to see it inline too:
import matplotlib.pyplot as plt
plt.show()

print("Saved to /content/output/confusion_matrix.png")
# Out:
# Saved to /content/output/confusion_matrix.png

# %%
# !ls -la /content/output
# Out:
# total 3013204
# drwxr-xr-x 3 root root      4096 Sep 26 11:53 .
# drwxr-xr-x 1 root root      4096 Sep 26 10:35 ..
# -rw-r--r-- 1 root root 536485397 Sep 26 11:00 checkpoint0009.pth
# -rw-r--r-- 1 root root 536485397 Sep 26 11:26 checkpoint0019.pth
# -rw-r--r-- 1 root root 536485397 Sep 26 11:52 checkpoint0029.pth
# -rw-r--r-- 1 root root 402396538 Sep 26 11:51 checkpoint_best_ema.pth
# -rw-r--r-- 1 root root 402404758 Sep 26 10:52 checkpoint_best_regular.pth
# -rw-r--r-- 1 root root 134098607 Sep 26 11:53 checkpoint_best_total.pth
# -rw-r--r-- 1 root root 536475141 Sep 26 11:52 checkpoint.pth
# drwxr-xr-x 2 root root      4096 Sep 26 10:37 eval
# -rw-r--r-- 1 root root     13092 Sep 26 11:53 events.out.tfevents.1758882905.4765205e25b6.347.0
# -rw-r--r-- 1 root root    457188 Sep 26 11:53 log.txt
# -rw-r--r-- 1 root root    161797 Sep 26 11:53 metrics_plot.png
# -rw-r--r-- 1 root root      8545 Sep 26 11:53 results.json

# %% [markdown]
# ## Evaluate Fine-tuned RF-DETR Model

# %% [markdown]
# Before benchmarking the model, we need to load the best saved checkpoint. To ensure it fits on the GPU, we first need to free up GPU memory. This involves deleting any remaining references to previously used objects, triggering Python’s garbage collector, and clearing the CUDA memory cache.

# %%
import gc
import torch
import weakref

def cleanup_gpu_memory(obj=None, verbose: bool = False):

    if not torch.cuda.is_available():
        if verbose:
            print("[INFO] CUDA is not available. No GPU cleanup needed.")
        return

    def get_memory_stats():
        allocated = torch.cuda.memory_allocated()
        reserved = torch.cuda.memory_reserved()
        return allocated, reserved

    torch.cuda.synchronize()

    if verbose:
        alloc, reserv = get_memory_stats()
        print(f"[Before] Allocated: {alloc / 1024**2:.2f} MB | Reserved: {reserv / 1024**2:.2f} MB")

    # Ensure we drop all strong references
    if obj is not None:
        ref = weakref.ref(obj)
        del obj
        if ref() is not None and verbose:
            print("[WARNING] Object not fully garbage collected yet.")

    gc.collect()
    torch.cuda.empty_cache()
    torch.cuda.ipc_collect()

    torch.cuda.synchronize()

    if verbose:
        alloc, reserv = get_memory_stats()
        print(f"[After]  Allocated: {alloc / 1024**2:.2f} MB | Reserved: {reserv / 1024**2:.2f} MB")

# %%
cleanup_gpu_memory(model, verbose=True)
# Out:
# [Before] Allocated: 146.58 MB | Reserved: 20880.00 MB
# [WARNING] Object not fully garbage collected yet.
# [After]  Allocated: 146.58 MB | Reserved: 310.00 MB

# %% [markdown]
# We load the best-performing model from the `checkpoint_best_total.pth` file using the `RFDETRMedium` class. This checkpoint contains the trained weights from our most successful training run. After loading, we call `optimize_for_inference()`, which prepares the model for efficient inference.

# %%
model = RFDETRMedium(pretrain_weights="/content/output/checkpoint_best_total.pth")
model.optimize_for_inference()
# Out:
# Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# WARNING:rfdetr.main:num_classes mismatch: pretrain weights has 30 classes, but your model has 90 classes
# reinitializing detection head with 30 classes
# Loading pretrain weights
# Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# torch.as_tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
# Iterating over a tensor might cause the trace to be incorrect. Passing a tensor of different shape won't change the number of iterations executed (and might lead to errors or silently give incorrect results).
# torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
# torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
# Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# Iterating over a tensor might cause the trace to be incorrect. Passing a tensor of different shape won't change the number of iterations executed (and might lead to errors or silently give incorrect results).
# Iterating over a tensor might cause the trace to be incorrect. Passing a tensor of different shape won't change the number of iterations executed (and might lead to errors or silently give incorrect results).

# %%
import supervision as sv

ds = sv.DetectionDataset.from_coco(
    images_directory_path=f"{dataset.location}/test",
    annotations_path=f"{dataset.location}/test/_annotations.coco.json",
)

# %%
import supervision as sv
from tqdm import tqdm
from supervision.metrics import MeanAveragePrecision

targets = []
predictions = []

for path, image, annotations in tqdm(ds):
    image = Image.open(path)
    detections = model.predict(image, threshold=0)

    targets.append(annotations)
    predictions.append(detections)
# Out:
# 100%|██████████| 450/450 [00:11<00:00, 37.59it/s]

# %%
map_metric = MeanAveragePrecision()
map_result = map_metric.update(predictions, targets).compute()
print(map_result)
# Out:
# Average Precision (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.740
# Average Precision (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.981
# Average Precision (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.891
# Average Precision (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.479
# Average Precision (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ]                 = 0.623
# Average Precision (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ]                 = 0.761

# %% [markdown]
# ## Run Inference with Fine-tuned RF-DETR Model

# %%
from rfdetr import RFDETRBase
import supervision as sv
from PIL import Image

path, image, annotations = ds[0]
image = Image.open(path)

detections = model.predict(image, threshold=0.5)

text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)
color = sv.ColorPalette.from_hex([
    "#ffff00", "#ff9b00", "#ff66ff", "#3399ff", "#ff66b2", "#ff8080",
    "#b266ff", "#9999ff", "#66ffff", "#33ff99", "#66ff66", "#99ff00"
])

bbox_annotator = sv.BoxAnnotator(color=color,thickness=thickness)
label_annotator = sv.LabelAnnotator(
    color=color,
    text_color=sv.Color.BLACK,
    text_scale=text_scale)

annotations_labels = [
    f"{ds.classes[class_id]}"
    for class_id
    in annotations.class_id
]

detections_labels = [
    f"{ds.classes[class_id]} {confidence:.2f}"
    for class_id, confidence
    in zip(detections.class_id, detections.confidence)
]

annotation_image = image.copy()
annotation_image = bbox_annotator.annotate(annotation_image, annotations)
annotation_image = label_annotator.annotate(annotation_image, annotations, annotations_labels)

detections_image = image.copy()
detections_image = bbox_annotator.annotate(detections_image, detections)
detections_image = label_annotator.annotate(detections_image, detections, detections_labels)

sv.plot_images_grid(images=[annotation_image, detections_image], grid_size=(1, 2), titles=["Annotation", "Detection"])
